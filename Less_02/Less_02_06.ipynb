# %% [markdown]
# <a href="https://colab.research.google.com/github/MaximTislenko/DS_in_MED/blob/main/Less_02_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np

# %%
# !wget https://github.com/MaximTislenko/DS_in_MED/raw/main/clinical.project-tcga-dlbc.2023-09-20.tar.gz
# Out:
# --2023-10-04 19:36:44--  https://github.com/MaximTislenko/DS_in_MED/raw/main/clinical.project-tcga-dlbc.2023-09-20.tar.gz
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/MaximTislenko/DS_in_MED/main/clinical.project-tcga-dlbc.2023-09-20.tar.gz [following]
# --2023-10-04 19:36:45--  https://raw.githubusercontent.com/MaximTislenko/DS_in_MED/main/clinical.project-tcga-dlbc.2023-09-20.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9344 (9.1K) [application/octet-stream]
# Saving to: ‘clinical.project-tcga-dlbc.2023-09-20.tar.gz’
#
# clinical.project-tc 100%[===================>]   9.12K  --.-KB/s    in 0s
#
# 2023-10-04 19:36:45 (73.9 MB/s) - ‘clinical.project-tcga-dlbc.2023-09-20.tar.gz’ saved [9344/9344]

# %%
import tarfile
zipfile = '/content/clinical.project-tcga-dlbc.2023-09-20.tar.gz'
if zipfile.endswith("tar.gz"):
    tar = tarfile.open(zipfile, "r:gz")
elif zipfile.endswith("tar"):
    tar = tarfile.open(zipfile, "r:")
tar.extractall()
tar.close()

# %% [markdown]
# ##Видимо клиническая картина
# Столбцы:
# * 'case_id' - **идентификатор амбулаторной/стационарной карты**,
# * 'case_submitter_id'- **идентификатор источника данных**,
# * 'project_id' - **идентификатор проекта**,
# * 'age_at_index' - **возраст на момент описания клиники**,
# * 'age_is_obfuscated' - **возраст неизвестен?**,
# * 'cause_of_death' - **причина смерти**,
# * 'cause_of_death_source' - **причина смерти источник**,
# * 'country_of_residence_at_enrollment' - **страна проживания на момент регистрации**,
# * 'days_to_birth' - **дата рождения**,
# * 'days_to_death' - **дата смерти**,
# * 'ethnicity' - **этническая принадлежность**,
# * 'gender' - **пол**,
# * 'occupation_duration_years' - **трудовой стаж, лет**,
# * 'premature_at_birth' - **недоношенный при рождении**,
# * 'race' - **расса**,
# * 'vital_status' - **жизненый уровень**,
# * 'weeks_gestation_at_birth' - **неделя гестации при рождении**,
# * 'year_of_birth' - **год рождения**,
# * 'year_of_death' - **год смерти**,
# * 'adrenal_hormone' - **гормоны надпочечников** ,
# * 'age_at_diagnosis' - **продолжительность болезни**,
#
# #AJCC - Американский объединенный комитет по раку
# * 'ajcc_clinical_m'- **продолжительность проявления клин.проявлений, мес??**,
# * 'ajcc_clinical_n'- **продолжительность проявления клин.проявлений, нед??**,
# * 'ajcc_clinical_stage' - **продолжительность стадии клин.проявлений??**
# * 'ajcc_clinical_t' - **продолжительность проявления клин.проявлений, час??**,
# * 'ajcc_pathologic_m'- **продолжительность заболевания, мес**,
# * 'ajcc_pathologic_n'- **продолжительность заболевания, нед**,
# * 'ajcc_pathologic_stage - **продолжительность стадии заболевания**',
# * 'ajcc_pathologic_t'- **продолжительность заболевания, час**,
# * 'ajcc_staging_system_edition - ',
# * 'anaplasia_present',
# * 'anaplasia_present_type',
# * 'ann_arbor_b_symptoms',
# * 'ann_arbor_b_symptoms_described',
# * 'ann_arbor_clinical_stage',
# * 'ann_arbor_extranodal_involvement',
# * 'ann_arbor_pathologic_stage',
# * 'best_overall_response',
# * 'breslow_thickness',
# * 'burkitt_lymphoma_clinical_variant',
# * 'child_pugh_classification',
# * 'circumferential_resection_margin',
# * 'classification_of_tumor',
# * 'cog_liver_stage',
# * 'cog_neuroblastoma_risk_group',
# * 'cog_renal_stage',
# * 'cog_rhabdomyosarcoma_risk_group',
# * 'days_to_best_overall_response',
# * 'days_to_diagnosis',
# * 'days_to_last_follow_up',
# * 'days_to_last_known_disease_status',
# * 'days_to_recurrence',
# * 'eln_risk_classification',
# * 'enneking_msts_grade',
# * 'enneking_msts_metastasis',
# * 'enneking_msts_stage',
# * 'enneking_msts_tumor_site',
# * 'esophageal_columnar_dysplasia_degree',
# * 'esophageal_columnar_metaplasia_present',
# * 'figo_stage',
# * 'figo_staging_edition_year',
# * 'first_symptom_prior_to_diagnosis',
# * 'gastric_esophageal_junction_involvement',
# * 'gleason_grade_group',
# * 'gleason_grade_tertiary',
# * 'gleason_patterns_percent',
# * 'goblet_cells_columnar_mucosa_present',
# * 'greatest_tumor_dimension',
# * 'gross_tumor_weight',
# * 'icd_10_code',
# * 'igcccg_stage',
# * 'inpc_grade',
# * 'inpc_histologic_group',
# * 'inrg_stage',
# * 'inss_stage',
# * 'international_prognostic_index',
# * 'irs_group',
# * 'irs_stage',
# * 'ishak_fibrosis_score',
# * 'iss_stage',
# * 'largest_extrapelvic_peritoneal_focus',
# * 'last_known_disease_status',
# * 'laterality',
# * 'lymph_node_involved_site',
# * 'lymph_nodes_positive',
# * 'lymph_nodes_tested',
# * 'lymphatic_invasion_present',
# * 'margin_distance',
# * 'margins_involved_site',
# * 'masaoka_stage',
# * 'medulloblastoma_molecular_classification',
# * 'metastasis_at_diagnosis',
# * 'metastasis_at_diagnosis_site',
# * 'method_of_diagnosis',
# * 'micropapillary_features',
# * 'mitosis_karyorrhexis_index',
# * 'mitotic_count',
# * 'morphology',
# * 'non_nodal_regional_disease',
# * 'non_nodal_tumor_deposits',
# * 'ovarian_specimen_status',
# * 'ovarian_surface_involvement',
# * 'papillary_renal_cell_type',
# * 'percent_tumor_invasion',
# * 'perineural_invasion_present',
# * 'peripancreatic_lymph_nodes_positive',
# * 'peripancreatic_lymph_nodes_tested',
# * 'peritoneal_fluid_cytological_status',
# * 'pregnant_at_diagnosis',
# * 'primary_diagnosis',
# * 'primary_disease',
# * 'primary_gleason_grade',
# * 'prior_malignancy',
# * 'prior_treatment',
# * 'progression_or_recurrence',
# * 'residual_disease',
# * 'satellite_nodule_present',
# * 'secondary_gleason_grade',
# * 'site_of_resection_or_biopsy',
# * 'sites_of_involvement',
# * 'supratentorial_localization',
# * 'synchronous_malignancy',
# * 'tissue_or_organ_of_origin',
# * 'transglottic_ex*tension',
# * 'tumor_confined_to_organ_of_origin',
# * 'tumor_depth',
# * 'tumor_focality',
# * 'tumor_grade',
# * 'tumor_largest_dimension_diameter',
# * 'tumor_regression_grade',
# * 'tumor_stage',
# * 'vascular_invasion_present',
# * 'vascular_invasion_type',
# * 'weiss_assessment_score',
# * 'who_cns_grade',
# * 'who_nte_grade',
# * 'wilms_tumor_histologic_subtype',
# * 'year_of_diagnosis',
# * 'chemo_concurrent_to_radiation',
# * 'days_to_treatment_end',
# * 'days_to_treatment_start',
# * 'initial_disease_status',
# * 'number_of_cycles',
# * 'reason_treatment_ended',
# * 'regimen_or_line_of_therapy',
# * 'route_of_administration',
# * 'therapeutic_agents',
# * 'treatment_anatomic_site',
# * 'treatment_arm',
# * 'treatment_dose',
# * 'treatment_dose_units',
# * 'treatment_effect',
# * 'treatment_effect_indicator',
# * 'treatment_frequency',
# * 'treatment_intent_type',
# * 'treatment_or_therapy',
# * 'treatment_outcome',
# * 'treatment_type'

# %%
clin = pd.read_csv('/content/clinical.tsv', sep=None, engine='python')
# clin[clin == "'--"] = None
# clin.dropna(axis= 1, how= 'all', inplace= True)
# clin.describe()

# %%
# clin = pd.read_csv('/content/clinical.tsv', sep=None, engine='python')
# clin

# %%
# clin[clin == "'--"] = None

# %%
# for name, values in clin.items():
#   if clin[name].all() == None:
#     clin.dropna([name], axis= 1, how= 'all', inplace= True)

# %%
# clin.dropna(axis= 1, how= 'all', inplace= True)

# %%
# for name, values in clin.items():
#   if clin[name].any == False:
#     clin.drop([name], axis= 1, how= 'all', inplace= True)

# %%
# clin['cause_of_death'].unique()

# %%
# for n in clin.columns:
#   if clin[n].any() == False:
#     clin.dropna(axis='columns',how='all', inplace=True)

# %%
clin.shape
# Out:
# (106, 158)

# %%
# clin.columns.values.tolist ()

# %%
clin.describe()
# Out:
#                                      case_id case_submitter_id project_id  \
# count                                    106               106        106
# unique                                    58                58          1
# top     0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# freq                                       2                 2        106
#
#        age_at_index age_is_obfuscated cause_of_death cause_of_death_source  \
# count           106               106            106                   106
# unique           35                 1              1                     1
# top             '--               '--            '--                   '--
# freq             10               106            106                   106
#
#        country_of_residence_at_enrollment days_to_birth days_to_death  ...  \
# count                                 106           106           106  ...
# unique                                  1            49            10  ...
# top                                   '--           '--           '--  ...
# freq                                  106            10            88  ...
#
#        treatment_arm treatment_dose treatment_dose_units treatment_effect  \
# count            106            106                  106              106
# unique             1              1                    1                1
# top              '--            '--                  '--              '--
# freq             106            106                  106              106
#
#        treatment_effect_indicator treatment_frequency treatment_intent_type  \
# count                         106                 106                   106
# unique                          1                   1                     1
# top                           '--                 '--                   '--
# freq                          106                 106                   106
#
#        treatment_or_therapy treatment_outcome               treatment_type
# count                   106               106                          106
# unique                    4                 1                            3
# top                     yes               '--  Pharmaceutical Therapy, NOS
# freq                     51               106                           48
#
# [4 rows x 158 columns]

# %%
# clin.loc[clin['ajcc_staging_system_edition'] == "'--", 'ajcc_staging_system_edition'] = ''

# %%
# clin['ajcc_staging_system_edition']

# %%
replacement = {"'--" : ""}
for name, values in clin.items ():
  values.map(replacement)



# print(n)

# %%
clin.loc[clin['ajcc_staging_system_edition'] != "'--"]
# Out:
# Empty DataFrame
# Columns: [case_id, case_submitter_id, project_id, age_at_index, age_is_obfuscated, cause_of_death, cause_of_death_source, country_of_residence_at_enrollment, days_to_birth, days_to_death, ethnicity, gender, occupation_duration_years, premature_at_birth, race, vital_status, weeks_gestation_at_birth, year_of_birth, year_of_death, adrenal_hormone, age_at_diagnosis, ajcc_clinical_m, ajcc_clinical_n, ajcc_clinical_stage, ajcc_clinical_t, ajcc_pathologic_m, ajcc_pathologic_n, ajcc_pathologic_stage, ajcc_pathologic_t, ajcc_staging_system_edition, anaplasia_present, anaplasia_present_type, ann_arbor_b_symptoms, ann_arbor_b_symptoms_described, ann_arbor_clinical_stage, ann_arbor_extranodal_involvement, ann_arbor_pathologic_stage, best_overall_response, breslow_thickness, burkitt_lymphoma_clinical_variant, child_pugh_classification, circumferential_resection_margin, classification_of_tumor, cog_liver_stage, cog_neuroblastoma_risk_group, cog_renal_stage, cog_rhabdomyosarcoma_risk_group, days_to_best_overall_response, days_to_diagnosis, days_to_last_follow_up, days_to_last_known_disease_status, days_to_recurrence, eln_risk_classification, enneking_msts_grade, enneking_msts_metastasis, enneking_msts_stage, enneking_msts_tumor_site, esophageal_columnar_dysplasia_degree, esophageal_columnar_metaplasia_present, figo_stage, figo_staging_edition_year, first_symptom_prior_to_diagnosis, gastric_esophageal_junction_involvement, gleason_grade_group, gleason_grade_tertiary, gleason_patterns_percent, goblet_cells_columnar_mucosa_present, greatest_tumor_dimension, gross_tumor_weight, icd_10_code, igcccg_stage, inpc_grade, inpc_histologic_group, inrg_stage, inss_stage, international_prognostic_index, irs_group, irs_stage, ishak_fibrosis_score, iss_stage, largest_extrapelvic_peritoneal_focus, last_known_disease_status, laterality, lymph_node_involved_site, lymph_nodes_positive, lymph_nodes_tested, lymphatic_invasion_present, margin_distance, margins_involved_site, masaoka_stage, medulloblastoma_molecular_classification, metastasis_at_diagnosis, metastasis_at_diagnosis_site, method_of_diagnosis, micropapillary_features, mitosis_karyorrhexis_index, mitotic_count, morphology, non_nodal_regional_disease, non_nodal_tumor_deposits, ...]
# Index: []
#
# [0 rows x 158 columns]

# %% [markdown]
# ##Видимо Группы риска (вредные привычки).
# #!NB Самая старая женьщина в Мире всю жизнь курила и лопала шоколад (прожила 120 лет)
#
# Колонки:
# * 'case_id' ,
# * 'case_submitter_id',
# * 'project_id',
# * 'age_at_onset',
# * 'alcohol_days_per_week',
# * 'alcohol_drinks_per_day',
# * 'alcohol_history',
# * 'alcohol_intensity',
# * 'alcohol_type',
# * 'asbestos_exposure',
# * 'bmi',
# * 'cigarettes_per_day',
# * 'coal_dust_exposure',
# * 'environmental_tobacco_smoke_exposure',
# * 'exposure_duration',
# * 'exposure_duration_years',
# * 'exposure_type',
# * 'height',
# * 'marijuana_use_per_week',
# * 'pack_years_smoked',
# * 'parent_with_radiation_exposure',
# * 'radon_exposure',
# * 'respirable_crystalline_silica_exposure',
# * 'secondhand_smoke_as_child',
# * 'smokeless_tobacco_quit_age',
# * 'smoking_frequency',
# * 'time_between_waking_and_first_smoke',
# * 'tobacco_smoking_onset_year',
# * 'tobacco_smoking_quit_year',
# * 'tobacco_smoking_status',
# * 'tobacco_use_per_day',
# * 'type_of_smoke_exposure',
# * 'type_of_tobacco_used',
# * 'weight',
# * 'years_smoked'

# %%
exposure = pd.read_csv('/content/exposure.tsv', sep=None)
# exposure
# Out:
# <ipython-input-19-91fbf7ee888d>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   exposure = pd.read_csv('/content/exposure.tsv', sep=None)

# %%
# exposure.columns.values.tolist ()

# %%
exposure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 35 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   case_id                                 48 non-null     object
#  1   case_submitter_id                       48 non-null     object
#  2   project_id                              48 non-null     object
#  3   age_at_onset                            48 non-null     object
#  4   alcohol_days_per_week                   48 non-null     object
#  5   alcohol_drinks_per_day                  48 non-null     object
#  6   alcohol_history                         48 non-null     object
#  7   alcohol_intensity                       48 non-null     object
#  8   alcohol_type                            48 non-null     object
#  9   asbestos_exposure                       48 non-null     object
#  10  bmi                                     48 non-null     object
#  11  cigarettes_per_day                      48 non-null     object
#  12  coal_dust_exposure                      48 non-null     object
#  13  environmental_tobacco_smoke_exposure    48 non-null     object
#  14  exposure_duration                       48 non-null     object
#  15  exposure_duration_years                 48 non-null     object
#  16  exposure_type                           48 non-null     object
#  17  height                                  48 non-null     object
#  18  marijuana_use_per_week                  48 non-null     object
#  19  pack_years_smoked                       48 non-null     object
#  20  parent_with_radiation_exposure          48 non-null     object
#  21  radon_exposure                          48 non-null     object
#  22  respirable_crystalline_silica_exposure  48 non-null     object
#  23  secondhand_smoke_as_child               48 non-null     object
#  24  smokeless_tobacco_quit_age              48 non-null     object
#  25  smoking_frequency                       48 non-null     object
#  26  time_between_waking_and_first_smoke     48 non-null     object
#  27  tobacco_smoking_onset_year              48 non-null     object
#  28  tobacco_smoking_quit_year               48 non-null     object
#  29  tobacco_smoking_status                  48 non-null     object
#  30  tobacco_use_per_day                     48 non-null     object
#  31  type_of_smoke_exposure                  48 non-null     object
#  32  type_of_tobacco_used                    48 non-null     object
#  33  weight                                  48 non-null     object
#  34  years_smoked                            48 non-null     object
# dtypes: object(35)
# memory usage: 13.2+ KB

# %%
exposure[exposure == "'--"] = None
exposure.dropna(axis= 1, how= 'all', inplace= True)
exposure.info()
# clin.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   case_id            48 non-null     object
#  1   case_submitter_id  48 non-null     object
#  2   project_id         48 non-null     object
#  3   alcohol_history    48 non-null     object
# dtypes: object(4)
# memory usage: 1.6+ KB

# %% [markdown]
# ##Видимо Семейный анамнез (история семьи)
# Но записей нет
# Столбцы:
# * 'case_id',
# * 'case_submitter_id',
# * 'project_id',
# * 'relationship_age_at_diagnosis',
# * 'relationship_gender',
# * 'relationship_primary_diagnosis',
# * 'relationship_type',
# * 'relative_with_cancer_history',
# * 'relatives_with_cancer_history_count'

# %%
fam_hist = pd.read_csv('/content/family_history.tsv', sep= None)
# fam_hist.info()
# Out:
# <ipython-input-23-b54e295bc04e>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   fam_hist = pd.read_csv('/content/family_history.tsv', sep= None)

# %% [markdown]
# ##Видимо Исход (дальнейшее наблюдение, диспансеризация)
# Но записей нет
#
# Столбцы:
# * 'case_id',
# * 'case_submitter_id',
# * 'project_id',
# * 'adverse_event',
# * 'adverse_event_grade',
# * 'aids_risk_factors',
# * 'barretts_esophagus_goblet_cells_present',
# * 'bmi',
# * 'body_surface_area',
# * 'cause_of_response',
# * 'cd4_count',
# * 'cdc_hiv_risk_factors',
# * 'comorbidity',
# * 'comorbidity_method_of_diagnosis',
# * 'days_to_adverse_event',
# * 'days_to_comorbidity',
# * 'days_to_follow_up',
# * 'days_to_imaging',
# * 'days_to_progression',
# * 'days_to_progression_free',
# * 'days_to_recurrence',
# * 'diabetes_treatment_type',
# * 'disease_response',
# * 'dlco_ref_predictive_percent',
# * 'ecog_performance_status',
# * 'evidence_of_recurrence_type',
# * 'eye_color',
# * 'fev1_fvc_post_bronch_percent',
# * 'fev1_fvc_pre_bronch_percent',
# * 'fev1_ref_post_bronch_percent',
# * 'fev1_ref_pre_bronch_percent',
# * 'follow_up_id',
# * 'follow_up_submitter_id',
# * 'haart_treatment_indicator',
# * 'height',
# * 'hepatitis_sustained_virological_response',
# * 'history_of_tumor',
# * 'history_of_tumor_type',
# * 'hiv_viral_load',
# * 'hormonal_contraceptive_type',
# * 'hormonal_contraceptive_use',
# * 'hormone_replacement_therapy_type',
# * 'hpv_positive_type',
# * 'hysterectomy_margins_involved',
# * 'hysterectomy_type',
# * 'imaging_result',
# * 'imaging_type',
# * 'immunosuppressive_treatment_type',
# * 'karnofsky_performance_status',
# * 'menopause_status',
# * 'nadir_cd4_count',
# * 'pancreatitis_onset_year',
# * 'pregnancy_outcome',
# * 'procedures_performed',
# * 'progression_or_recurrence',
# * 'progression_or_recurrence_anatomic_site',
# * 'progression_or_recurrence_type',
# * 'recist_targeted_regions_number',
# * 'recist_targeted_regions_sum',
# * 'reflux_treatment_type',
# * 'risk_factor',
# * 'risk_factor_treatment',
# * 'scan_tracer_used',
# * 'undescended_testis_corrected',
# * 'undescended_testis_corrected_age',
# * 'undescended_testis_corrected_laterality',
# * 'undescended_testis_corrected_method',
# * 'undescended_testis_history',
# * 'undescended_testis_history_laterality',
# * 'viral_hepatitis_serologies',
# * 'weight',
# * 'aa_change',
# * 'antigen',
# * 'biospecimen_type',
# * 'biospecimen_volume',
# * 'blood_test_normal_range_lower',
# * 'blood_test_normal_range_upper',
# * 'cell_count',
# * 'chromosome',
# * 'clonality',
# * 'copy_number',
# * 'cytoband',
# * 'days_to_test',
# * 'exon',
# * 'gene_symbol',
# * 'histone_family',
# * 'histone_variant',
# * 'intron',
# * 'laboratory_test',
# * 'loci_abnormal_count',
# * 'loci_count',
# * 'locus',
# * 'mismatch_repair_mutation',
# * 'mitotic_count',
# * 'mitotic_total_area',
# * 'molecular_analysis_method',
# * 'molecular_consequence',
# * 'molecular_test_id',
# * 'molecular_test_submitter_id',
# * 'pathogenicity',
# * 'ploidy',
# * 'second_exon',
# * 'second_gene_symbol',
# * 'specialized_molecular_test',
# * 'test_analyte_type',
# * 'test_result',
# * 'test_units',
# * 'test_value',
# * 'transcript',
# * 'variant_origin',
# * 'variant_type',
# * 'zygosity'

# %%
foll_up = pd.read_csv('/content/follow_up.tsv', sep= None)
# foll_up
# Out:
# <ipython-input-24-f5634306870d>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   foll_up = pd.read_csv('/content/follow_up.tsv', sep= None)

# %%
# foll_up.columns.values.tolist()

# %%
# foll_up.info()

# %% [markdown]
# ##Видимо Подробности патологии
# Но тоже пустая
#
# Столбцы:
# * 'case_id',
# * 'case_submitter_id',
# * 'project_id',
# * 'diagnosis_id',
# * 'diagnosis_submitter_id',
# * 'additional_pathology_findings',
# * 'anaplasia_present',
# * 'anaplasia_present_type',
# * 'bone_marrow_malignant_cells',
# * 'breslow_thickness',
# * 'circumferential_resection_margin',
# * 'columnar_mucosa_present',
# * 'consistent_pathology_review',
# * 'dysplasia_degree',
# * 'dysplasia_type',
# * 'greatest_tumor_dimension',
# * 'gross_tumor_weight',
# * 'largest_extrapelvic_peritoneal_focus',
# * 'lymph_node_involved_site',
# * 'lymph_node_involvement',
# * 'lymph_nodes_positive',
# * 'lymph_nodes_tested',
# * 'lymphatic_invasion_present',
# * 'margin_status',
# * 'metaplasia_present',
# * 'morphologic_architectural_pattern',
# * 'necrosis_percent',
# * 'necrosis_present',
# * 'non_nodal_regional_disease',
# * 'non_nodal_tumor_deposits',
# * 'number_proliferating_cells',
# * 'pathology_detail_id',
# * 'pathology_detail_submitter_id',
# * 'percent_tumor_invasion',
# * 'perineural_invasion_present',
# * 'peripancreatic_lymph_nodes_positive',
# * 'peripancreatic_lymph_nodes_tested',
# * 'prostatic_chips_positive_count',
# * 'prostatic_chips_total_count',
# * 'prostatic_involvement_percent',
# * 'residual_tumor',
# * 'rhabdoid_percent',
# * 'rhabdoid_present',
# * 'sarcomatoid_percent',
# * 'sarcomatoid_present',
# * 'size_extraocular_nodule',
# * 'transglottic_extension',
# * 'tumor_largest_dimension_diameter',
# * 'tumor_thickness',
# * 'vascular_invasion_present',
# * 'vascular_invasion_type'

# %%
# path_det = pd.read_csv('/content/pathology_detail.tsv', sep=None)
# path_det

# %%
# path_det.columns.values.tolist()

# %%
# path_det.info()

# %% [markdown]
# #Заключение
# В архиве представлено 5 таблиц (Клиника, Группы риска, Семейный анамнез, Исход, Подробности патологии), 3 таблицы не заполнены. Поэтому в работу их не беру. Итого в работе 2 таблицы (Клиника(***clinical.tsv***) и Группы риска(***exposure.tsv***)).
# Для началы выберу столбцы в каждой таблице и объединю их по ***case_id***

# %%
clin.describe()
# Out:
#                                      case_id case_submitter_id project_id  \
# count                                    106               106        106
# unique                                    58                58          1
# top     0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# freq                                       2                 2        106
#
#        age_at_index age_is_obfuscated cause_of_death cause_of_death_source  \
# count           106               106            106                   106
# unique           35                 1              1                     1
# top             '--               '--            '--                   '--
# freq             10               106            106                   106
#
#        country_of_residence_at_enrollment days_to_birth days_to_death  ...  \
# count                                 106           106           106  ...
# unique                                  1            49            10  ...
# top                                   '--           '--           '--  ...
# freq                                  106            10            88  ...
#
#        treatment_arm treatment_dose treatment_dose_units treatment_effect  \
# count            106            106                  106              106
# unique             1              1                    1                1
# top              '--            '--                  '--              '--
# freq             106            106                  106              106
#
#        treatment_effect_indicator treatment_frequency treatment_intent_type  \
# count                         106                 106                   106
# unique                          1                   1                     1
# top                           '--                 '--                   '--
# freq                          106                 106                   106
#
#        treatment_or_therapy treatment_outcome               treatment_type
# count                   106               106                          106
# unique                    4                 1                            3
# top                     yes               '--  Pharmaceutical Therapy, NOS
# freq                     51               106                           48
#
# [4 rows x 158 columns]

# %% [markdown]
# ###Начнем удалять столбцы с одним уникальным значением

# %%
clin[clin == "'--"] = None
clin.dropna(axis= 1, how= 'all', inplace= True)
clin.describe()
# Out:
#                                      case_id case_submitter_id project_id  \
# count                                    106               106        106
# unique                                    58                58          1
# top     0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# freq                                       2                 2        106
#
#        age_at_index days_to_birth days_to_death               ethnicity  \
# count            96            96            18                      96
# unique           34            48             9                       2
# top              67        -22454           248  not hispanic or latino
# freq              6             2             2                      72
#
#         gender   race vital_status  ... prior_malignancy prior_treatment  \
# count       96     96           96  ...               96              96
# unique       2      3            2  ...                1               2
# top     female  white        Alive  ...               no              No
# freq        52     58           78  ...               96              94
#
#        progression_or_recurrence         site_of_resection_or_biopsy  \
# count                         96                                  96
# unique                         1                                  20
# top                 not reported  Lymph nodes of head, face and neck
# freq                          96                                  32
#
#        synchronous_malignancy           tissue_or_organ_of_origin  \
# count                      96                                  96
# unique                      1                                  20
# top                        No  Lymph nodes of head, face and neck
# freq                       96                                  32
#
#          tumor_grade year_of_diagnosis treatment_or_therapy  \
# count             96                96                   96
# unique             1                14                    3
# top     not reported              2013                  yes
# freq              96                18                   51
#
#                      treatment_type
# count                            96
# unique                            2
# top     Pharmaceutical Therapy, NOS
# freq                             48
#
# [4 rows x 33 columns]

# %%
clin.columns.values.tolist()
# Out:
# ['case_id',
#  'case_submitter_id',
#  'project_id',
#  'age_at_index',
#  'days_to_birth',
#  'days_to_death',
#  'ethnicity',
#  'gender',
#  'race',
#  'vital_status',
#  'year_of_birth',
#  'year_of_death',
#  'age_at_diagnosis',
#  'ann_arbor_b_symptoms',
#  'ann_arbor_clinical_stage',
#  'ann_arbor_extranodal_involvement',
#  'classification_of_tumor',
#  'days_to_diagnosis',
#  'days_to_last_follow_up',
#  'icd_10_code',
#  'last_known_disease_status',
#  'morphology',
#  'primary_diagnosis',
#  'prior_malignancy',
#  'prior_treatment',
#  'progression_or_recurrence',
#  'site_of_resection_or_biopsy',
#  'synchronous_malignancy',
#  'tissue_or_organ_of_origin',
#  'tumor_grade',
#  'year_of_diagnosis',
#  'treatment_or_therapy',
#  'treatment_type']

# %% [markdown]
# Остались столбцы:
# * 'case_id'- ***идентификатор амбулаторной/стационарной карты***,
# * 'case_submitter_id' - ***идентификатор источника данных***,
# * 'project_id' - ***идентификатор проекта***,
# * 'age_at_index' - ***возраст на момент описания клиники***,
# * 'days_to_birth' - ***дата рождения***,
# * 'days_to_death' - ***дата смерти***,
# * 'ethnicity' - ***этническая принадлежность***,
# * 'gender' - ***пол***,
# * 'race' - ***расса***,
# * 'vital_status' - ***жизненый уровень***,
# * 'year_of_birth' - ***год рождения***,
# * 'year_of_death' - ***год смерти***,
# * 'age_at_diagnosis' - ***продолжительность болезни***,
# * 'ann_arbor_b_symptoms' - ***стадирование симптомов по системе ANN-Arbor***,
# * 'ann_arbor_clinical_stage' - ***стадирование клиники по системе ANN-Arbor***,
# * 'ann_arbor_extranodal_involvement'- ***стадирование экстранодальное поражение по системе ANN-Arbor***,
# * 'classification_of_tumor' - ***классификация опухолей***,
# * 'days_to_diagnosis' - ***дней до диагностики***,
# * 'days_to_last_follow_up' - ***дней до последнего наблюдения***,
# * 'icd_10_code' - ***код по МКБ-10***,
# * 'last_known_disease_status' - ***последний известный статус заболевания***,
# * 'morphology' - ***морфология***,
# * 'primary_diagnosis' - ***первичный диагноз***,
# * 'prior_malignancy' - ***предшествующее злокачественное новообразование***,
# * 'prior_treatment' - ***предшествующее лечение***,
# * 'progression_or_recurrence' - ***прогрессирование или рецидив***,
# * 'site_of_resection_or_biopsy' - ***место резекции или биопсии***,
# * 'synchronous_malignancy' - ***дополнительное злокачественное новообразование***,
# * 'tissue_or_organ_of_origin' - ***ткань или орган происхождения***,
# * 'tumor_grade' - ***степень опухоли***,
# * 'year_of_diagnosis' - ***год постановки диагноза***,
# * 'treatment_or_therapy' - ***консервативное или оперативное лечение***,
# * 'treatment_type' - ***тип терапии***
# их и переведу.

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
print(clin['age_at_index'].isna)
# Out:
# <bound method Series.isna of 0        61
# 1        61
# 2        73
# 3        73
# 4        27
# 5        27
# 6        60
# 7        60
# 8        67
# 9        67
# 10       72
# 11       72
# 12       45
# 13       45
# 14     None
# 15       28
# 16       28
# 17     None
# 18       63
# 19       63
# 20       23
# 21       23
# 22       46
# 23       46
# 24       57
# 25       57
# 26       70
# 27       70
# 28       67
# 29       67
# 30       58
# 31       58
# 32     None
# 33     None
# 34       69
# 35       69
# 36     None
# 37       63
# 38       63
# 39       37
# 40       37
# 41       66
# 42       66
# 43       51
# 44       51
# 45       58
# 46       58
# 47       43
# 48       43
# 49       82
# 50       82
# 51       56
# 52       56
# 53       75
# 54       75
# 55       67
# 56       67
# 57       40
# 58       40
# 59       55
# 60       55
# 61       70
# 62       70
# 63       64
# 64       64
# 65       54
# 66       54
# 67       36
# 68       36
# 69     None
# 70       40
# 71       40
# 72       42
# 73       42
# 74     None
# 75     None
# 76       57
# 77       57
# 78     None
# 79       62
# 80       62
# 81       70
# 82       70
# 83       48
# 84       48
# 85       69
# 86       69
# 87       54
# 88       54
# 89       51
# 90       51
# 91       57
# 92       57
# 93     None
# 94       74
# 95       74
# 96       61
# 97       61
# 98       46
# 99       46
# 100      52
# 101      52
# 102      38
# 103      38
# 104      77
# 105      77
# Name: age_at_index, dtype: object>

# %%
clin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   case_id                           106 non-null    object
#  1   case_submitter_id                 106 non-null    object
#  2   project_id                        106 non-null    object
#  3   age_at_index                      96 non-null     object
#  4   days_to_birth                     96 non-null     object
#  5   days_to_death                     18 non-null     object
#  6   ethnicity                         96 non-null     object
#  7   gender                            96 non-null     object
#  8   race                              96 non-null     object
#  9   vital_status                      96 non-null     object
#  10  year_of_birth                     96 non-null     object
#  11  year_of_death                     10 non-null     object
#  12  age_at_diagnosis                  96 non-null     object
#  13  ann_arbor_b_symptoms              92 non-null     object
#  14  ann_arbor_clinical_stage          84 non-null     object
#  15  ann_arbor_extranodal_involvement  92 non-null     object
#  16  classification_of_tumor           96 non-null     object
#  17  days_to_diagnosis                 96 non-null     object
#  18  days_to_last_follow_up            86 non-null     object
#  19  icd_10_code                       96 non-null     object
#  20  last_known_disease_status         96 non-null     object
#  21  morphology                        96 non-null     object
#  22  primary_diagnosis                 96 non-null     object
#  23  prior_malignancy                  96 non-null     object
#  24  prior_treatment                   96 non-null     object
#  25  progression_or_recurrence         96 non-null     object
#  26  site_of_resection_or_biopsy       96 non-null     object
#  27  synchronous_malignancy            96 non-null     object
#  28  tissue_or_organ_of_origin         96 non-null     object
#  29  tumor_grade                       96 non-null     object
#  30  year_of_diagnosis                 96 non-null     object
#  31  treatment_or_therapy              96 non-null     object
#  32  treatment_type                    96 non-null     object
# dtypes: object(33)
# memory usage: 27.5+ KB

# %% [markdown]
# В данной таблице 106 записей, только у 96 пациентов указан возраст и код по МКБ-10. Похоже в работу нужно взять только этих пациентов.

# %%
# df.dropna (subset=['assists'])
# df = df[df['ATR2'].notnull()]
from pandas.core.window.ewm import isna
clin_w = clin.dropna(subset=['age_at_index'])
clin_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 105
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   case_id                           96 non-null     object
#  1   case_submitter_id                 96 non-null     object
#  2   project_id                        96 non-null     object
#  3   age_at_index                      96 non-null     object
#  4   days_to_birth                     96 non-null     object
#  5   days_to_death                     18 non-null     object
#  6   ethnicity                         96 non-null     object
#  7   gender                            96 non-null     object
#  8   race                              96 non-null     object
#  9   vital_status                      96 non-null     object
#  10  year_of_birth                     96 non-null     object
#  11  year_of_death                     10 non-null     object
#  12  age_at_diagnosis                  96 non-null     object
#  13  ann_arbor_b_symptoms              92 non-null     object
#  14  ann_arbor_clinical_stage          84 non-null     object
#  15  ann_arbor_extranodal_involvement  92 non-null     object
#  16  classification_of_tumor           96 non-null     object
#  17  days_to_diagnosis                 96 non-null     object
#  18  days_to_last_follow_up            86 non-null     object
#  19  icd_10_code                       96 non-null     object
#  20  last_known_disease_status         96 non-null     object
#  21  morphology                        96 non-null     object
#  22  primary_diagnosis                 96 non-null     object
#  23  prior_malignancy                  96 non-null     object
#  24  prior_treatment                   96 non-null     object
#  25  progression_or_recurrence         96 non-null     object
#  26  site_of_resection_or_biopsy       96 non-null     object
#  27  synchronous_malignancy            96 non-null     object
#  28  tissue_or_organ_of_origin         96 non-null     object
#  29  tumor_grade                       96 non-null     object
#  30  year_of_diagnosis                 96 non-null     object
#  31  treatment_or_therapy              96 non-null     object
#  32  treatment_type                    96 non-null     object
# dtypes: object(33)
# memory usage: 25.5+ KB

# %%
clin_w.head(10)
# Out:
#                                 case_id case_submitter_id project_id  \
# 0  0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# 1  0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# 2  0bf573ac-cd1e-42d8-90cf-b30d7b08679c      TCGA-FA-A6HN  TCGA-DLBC
# 3  0bf573ac-cd1e-42d8-90cf-b30d7b08679c      TCGA-FA-A6HN  TCGA-DLBC
# 4  0e251c03-bf86-4ed8-b45d-3cbc97160502      TCGA-GS-A9U4  TCGA-DLBC
# 5  0e251c03-bf86-4ed8-b45d-3cbc97160502      TCGA-GS-A9U4  TCGA-DLBC
# 6  0e9fcccc-0630-408d-a121-2c6413824cb7      TCGA-FF-8062  TCGA-DLBC
# 7  0e9fcccc-0630-408d-a121-2c6413824cb7      TCGA-FF-8062  TCGA-DLBC
# 8  1843c82e-7a35-474f-9f79-c0a9af9aa09c      TCGA-FA-A4BB  TCGA-DLBC
# 9  1843c82e-7a35-474f-9f79-c0a9af9aa09c      TCGA-FA-A4BB  TCGA-DLBC
#
#   age_at_index days_to_birth days_to_death               ethnicity  gender  \
# 0           61        -22454           248  not hispanic or latino  female
# 1           61        -22454           248  not hispanic or latino  female
# 2           73        -27025            58  not hispanic or latino    male
# 3           73        -27025            58  not hispanic or latino    male
# 4           27        -10075           391      hispanic or latino  female
# 5           27        -10075           391      hispanic or latino  female
# 6           60        -21959          None  not hispanic or latino  female
# 7           60        -21959          None  not hispanic or latino  female
# 8           67        -24590          None  not hispanic or latino    male
# 9           67        -24590          None  not hispanic or latino    male
#
#     race vital_status year_of_birth year_of_death age_at_diagnosis  \
# 0  asian         Dead          1952          None            22454
# 1  asian         Dead          1952          None            22454
# 2  asian         Dead          1940          None            27025
# 3  asian         Dead          1940          None            27025
# 4  white         Dead          1984          2012            10075
# 5  white         Dead          1984          2012            10075
# 6  asian        Alive          1951          None            21959
# 7  asian        Alive          1951          None            21959
# 8  white        Alive          1945          None            24590
# 9  white        Alive          1945          None            24590
#
#   ann_arbor_b_symptoms ann_arbor_clinical_stage  \
# 0                   No                  Stage I
# 1                   No                  Stage I
# 2                   No                     None
# 3                   No                     None
# 4                   No                 Stage II
# 5                   No                 Stage II
# 6                   No                  Stage I
# 7                   No                  Stage I
# 8                  Yes                 Stage IV
# 9                  Yes                 Stage IV
#
#   ann_arbor_extranodal_involvement classification_of_tumor days_to_diagnosis  \
# 0                               No            not reported                 0
# 1                               No            not reported                 0
# 2                               No            not reported                 0
# 3                               No            not reported                 0
# 4                               No            not reported                 0
# 5                               No            not reported                 0
# 6                              Yes            not reported                 0
# 7                              Yes            not reported                 0
# 8                              Yes            not reported                 0
# 9                              Yes            not reported                 0
#
#   days_to_last_follow_up icd_10_code last_known_disease_status morphology  \
# 0                     22       C48.1              not reported     9680/3
# 1                     22       C48.1              not reported     9680/3
# 2                      6       C83.3              not reported     9680/3
# 3                      6       C83.3              not reported     9680/3
# 4                   None       C83.3              not reported     9680/3
# 5                   None       C83.3              not reported     9680/3
# 6                    679       C83.3              not reported     9680/3
# 7                    679       C83.3              not reported     9680/3
# 8                    132       C83.3              not reported     9680/3
# 9                    132       C83.3              not reported     9680/3
#
#                                 primary_diagnosis prior_malignancy  \
# 0  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 1  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 2  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 3  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 4  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 5  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 6  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 7  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 8  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 9  Malignant lymphoma, large B-cell, diffuse, NOS               no
#
#   prior_treatment progression_or_recurrence  \
# 0              No              not reported
# 1              No              not reported
# 2              No              not reported
# 3              No              not reported
# 4              No              not reported
# 5              No              not reported
# 6              No              not reported
# 7              No              not reported
# 8              No              not reported
# 9              No              not reported
#
#           site_of_resection_or_biopsy synchronous_malignancy  \
# 0         Intra-abdominal lymph nodes                     No
# 1         Intra-abdominal lymph nodes                     No
# 2  Lymph nodes of head, face and neck                     No
# 3  Lymph nodes of head, face and neck                     No
# 4  Lymph nodes of head, face and neck                     No
# 5  Lymph nodes of head, face and neck                     No
# 6                       Thyroid gland                     No
# 7                       Thyroid gland                     No
# 8        Lymph nodes of axilla or arm                     No
# 9        Lymph nodes of axilla or arm                     No
#
#             tissue_or_organ_of_origin   tumor_grade year_of_diagnosis  \
# 0         Intra-abdominal lymph nodes  not reported              2013
# 1         Intra-abdominal lymph nodes  not reported              2013
# 2  Lymph nodes of head, face and neck  not reported              2013
# 3  Lymph nodes of head, face and neck  not reported              2013
# 4  Lymph nodes of head, face and neck  not reported              2011
# 5  Lymph nodes of head, face and neck  not reported              2011
# 6                       Thyroid gland  not reported              2011
# 7                       Thyroid gland  not reported              2011
# 8        Lymph nodes of axilla or arm  not reported              2012
# 9        Lymph nodes of axilla or arm  not reported              2012
#
#   treatment_or_therapy               treatment_type
# 0                  yes  Pharmaceutical Therapy, NOS
# 1                   no       Radiation Therapy, NOS
# 2                   no       Radiation Therapy, NOS
# 3                  yes  Pharmaceutical Therapy, NOS
# 4                  yes  Pharmaceutical Therapy, NOS
# 5                   no       Radiation Therapy, NOS
# 6                  yes  Pharmaceutical Therapy, NOS
# 7                   no       Radiation Therapy, NOS
# 8                   no       Radiation Therapy, NOS
# 9                  yes  Pharmaceutical Therapy, NOS

# %% [markdown]
# Получили подчищенную табличку, с которой уже можно работать.
#
# Изменим типы объектов

# %%
for colname in ['age_at_diagnosis', 'days_to_birth', 'year_of_birth', 'age_at_diagnosis', 'days_to_diagnosis','year_of_diagnosis']:
  clin_w[colname] =  clin_w[colname].astype('int')
# Out:
# <ipython-input-38-b810250096ad>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clin_w[colname] =  clin_w[colname].astype('int')

# %%
# clin_w['age_at_diagnosis', 'days_to_birth', 'days_to_death', 'year_of_birth', 'year_of_death', 'age_at_diagnosis',
      #  'days_to_diagnosis', 'days_to_last_follow_up', 'year_of_diagnosis'].astype('int')

# %%
clin_w['age_at_diagnosis'] = clin_w['age_at_diagnosis'].astype('int')
clin_w['days_to_birth'] = clin_w['days_to_birth'].astype('int')
# Out:
# <ipython-input-40-d620ff810fd7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clin_w['age_at_diagnosis'] = clin_w['age_at_diagnosis'].astype('int')
# <ipython-input-40-d620ff810fd7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clin_w['days_to_birth'] = clin_w['days_to_birth'].astype('int')

# %%
clin_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 105
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   case_id                           96 non-null     object
#  1   case_submitter_id                 96 non-null     object
#  2   project_id                        96 non-null     object
#  3   age_at_index                      96 non-null     object
#  4   days_to_birth                     96 non-null     int64
#  5   days_to_death                     18 non-null     object
#  6   ethnicity                         96 non-null     object
#  7   gender                            96 non-null     object
#  8   race                              96 non-null     object
#  9   vital_status                      96 non-null     object
#  10  year_of_birth                     96 non-null     int64
#  11  year_of_death                     10 non-null     object
#  12  age_at_diagnosis                  96 non-null     int64
#  13  ann_arbor_b_symptoms              92 non-null     object
#  14  ann_arbor_clinical_stage          84 non-null     object
#  15  ann_arbor_extranodal_involvement  92 non-null     object
#  16  classification_of_tumor           96 non-null     object
#  17  days_to_diagnosis                 96 non-null     int64
#  18  days_to_last_follow_up            86 non-null     object
#  19  icd_10_code                       96 non-null     object
#  20  last_known_disease_status         96 non-null     object
#  21  morphology                        96 non-null     object
#  22  primary_diagnosis                 96 non-null     object
#  23  prior_malignancy                  96 non-null     object
#  24  prior_treatment                   96 non-null     object
#  25  progression_or_recurrence         96 non-null     object
#  26  site_of_resection_or_biopsy       96 non-null     object
#  27  synchronous_malignancy            96 non-null     object
#  28  tissue_or_organ_of_origin         96 non-null     object
#  29  tumor_grade                       96 non-null     object
#  30  year_of_diagnosis                 96 non-null     int64
#  31  treatment_or_therapy              96 non-null     object
#  32  treatment_type                    96 non-null     object
# dtypes: int64(5), object(28)
# memory usage: 25.5+ KB

# %%
clin_w.describe()
# Out:
#        days_to_birth  year_of_birth  age_at_diagnosis  days_to_diagnosis  \
# count      96.000000      96.000000         96.000000               96.0
# mean   -20731.354167    1952.875000      20731.354167                0.0
# std      5080.518956      15.092173       5080.518956                0.0
# min    -30256.000000    1923.000000       8493.000000                0.0
# 25%    -24607.750000    1941.000000      16998.250000                0.0
# 50%    -21146.500000    1951.500000      21146.500000                0.0
# 75%    -16998.250000    1963.250000      24607.750000                0.0
# max     -8493.000000    1987.000000      30256.000000                0.0
#
#        year_of_diagnosis
# count          96.000000
# mean         2009.145833
# std             5.005217
# min          1987.000000
# 25%          2009.000000
# 50%          2011.000000
# 75%          2012.000000
# max          2013.000000

# %%
clin_w.describe(include= 'all')
# Out:
#                                      case_id case_submitter_id project_id  \
# count                                     96                96         96
# unique                                    48                48          1
# top     0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# freq                                       2                 2         96
# mean                                     NaN               NaN        NaN
# std                                      NaN               NaN        NaN
# min                                      NaN               NaN        NaN
# 25%                                      NaN               NaN        NaN
# 50%                                      NaN               NaN        NaN
# 75%                                      NaN               NaN        NaN
# max                                      NaN               NaN        NaN
#
#        age_at_index  days_to_birth days_to_death               ethnicity  \
# count            96      96.000000            18                      96
# unique           34            NaN             9                       2
# top              67            NaN           248  not hispanic or latino
# freq              6            NaN             2                      72
# mean            NaN  -20731.354167           NaN                     NaN
# std             NaN    5080.518956           NaN                     NaN
# min             NaN  -30256.000000           NaN                     NaN
# 25%             NaN  -24607.750000           NaN                     NaN
# 50%             NaN  -21146.500000           NaN                     NaN
# 75%             NaN  -16998.250000           NaN                     NaN
# max             NaN   -8493.000000           NaN                     NaN
#
#         gender   race vital_status  year_of_birth year_of_death  \
# count       96     96           96      96.000000            10
# unique       2      3            2            NaN             4
# top     female  white        Alive            NaN          2012
# freq        52     58           78            NaN             4
# mean       NaN    NaN          NaN    1952.875000           NaN
# std        NaN    NaN          NaN      15.092173           NaN
# min        NaN    NaN          NaN    1923.000000           NaN
# 25%        NaN    NaN          NaN    1941.000000           NaN
# 50%        NaN    NaN          NaN    1951.500000           NaN
# 75%        NaN    NaN          NaN    1963.250000           NaN
# max        NaN    NaN          NaN    1987.000000           NaN
#
#         age_at_diagnosis ann_arbor_b_symptoms ann_arbor_clinical_stage  \
# count          96.000000                   92                       84
# unique               NaN                    2                        4
# top                  NaN                   No                 Stage II
# freq                 NaN                   70                       34
# mean        20731.354167                  NaN                      NaN
# std          5080.518956                  NaN                      NaN
# min          8493.000000                  NaN                      NaN
# 25%         16998.250000                  NaN                      NaN
# 50%         21146.500000                  NaN                      NaN
# 75%         24607.750000                  NaN                      NaN
# max         30256.000000                  NaN                      NaN
#
#        ann_arbor_extranodal_involvement classification_of_tumor  \
# count                                92                      96
# unique                                2                       1
# top                                  No            not reported
# freq                                 50                      96
# mean                                NaN                     NaN
# std                                 NaN                     NaN
# min                                 NaN                     NaN
# 25%                                 NaN                     NaN
# 50%                                 NaN                     NaN
# 75%                                 NaN                     NaN
# max                                 NaN                     NaN
#
#         days_to_diagnosis days_to_last_follow_up icd_10_code  \
# count                96.0                     86          96
# unique                NaN                     41          10
# top                   NaN                    132       C83.3
# freq                  NaN                      4          76
# mean                  0.0                    NaN         NaN
# std                   0.0                    NaN         NaN
# min                   0.0                    NaN         NaN
# 25%                   0.0                    NaN         NaN
# 50%                   0.0                    NaN         NaN
# 75%                   0.0                    NaN         NaN
# max                   0.0                    NaN         NaN
#
#        last_known_disease_status morphology  \
# count                         96         96
# unique                         1          1
# top                 not reported     9680/3
# freq                          96         96
# mean                         NaN        NaN
# std                          NaN        NaN
# min                          NaN        NaN
# 25%                          NaN        NaN
# 50%                          NaN        NaN
# 75%                          NaN        NaN
# max                          NaN        NaN
#
#                                      primary_diagnosis prior_malignancy  \
# count                                               96               96
# unique                                               1                1
# top     Malignant lymphoma, large B-cell, diffuse, NOS               no
# freq                                                96               96
# mean                                               NaN              NaN
# std                                                NaN              NaN
# min                                                NaN              NaN
# 25%                                                NaN              NaN
# 50%                                                NaN              NaN
# 75%                                                NaN              NaN
# max                                                NaN              NaN
#
#        prior_treatment progression_or_recurrence  \
# count               96                        96
# unique               2                         1
# top                 No              not reported
# freq                94                        96
# mean               NaN                       NaN
# std                NaN                       NaN
# min                NaN                       NaN
# 25%                NaN                       NaN
# 50%                NaN                       NaN
# 75%                NaN                       NaN
# max                NaN                       NaN
#
#                site_of_resection_or_biopsy synchronous_malignancy  \
# count                                   96                     96
# unique                                  20                      1
# top     Lymph nodes of head, face and neck                     No
# freq                                    32                     96
# mean                                   NaN                    NaN
# std                                    NaN                    NaN
# min                                    NaN                    NaN
# 25%                                    NaN                    NaN
# 50%                                    NaN                    NaN
# 75%                                    NaN                    NaN
# max                                    NaN                    NaN
#
#                  tissue_or_organ_of_origin   tumor_grade  year_of_diagnosis  \
# count                                   96            96          96.000000
# unique                                  20             1                NaN
# top     Lymph nodes of head, face and neck  not reported                NaN
# freq                                    32            96                NaN
# mean                                   NaN           NaN        2009.145833
# std                                    NaN           NaN           5.005217
# min                                    NaN           NaN        1987.000000
# 25%                                    NaN           NaN        2009.000000
# 50%                                    NaN           NaN        2011.000000
# 75%                                    NaN           NaN        2012.000000
# max                                    NaN           NaN        2013.000000
#
#        treatment_or_therapy               treatment_type
# count                    96                           96
# unique                    3                            2
# top                     yes  Pharmaceutical Therapy, NOS
# freq                     51                           48
# mean                    NaN                          NaN
# std                     NaN                          NaN
# min                     NaN                          NaN
# 25%                     NaN                          NaN
# 50%                     NaN                          NaN
# 75%                     NaN                          NaN
# max                     NaN                          NaN

# %%
clin_w.describe(percentiles= [0.05, 0.25, 0.5, 0.75, 0.95])
# Out:
#        days_to_birth  year_of_birth  age_at_diagnosis  days_to_diagnosis  \
# count      96.000000      96.000000         96.000000               96.0
# mean   -20731.354167    1952.875000      20731.354167                0.0
# std      5080.518956      15.092173       5080.518956                0.0
# min    -30256.000000    1923.000000       8493.000000                0.0
# 5%     -27468.000000    1929.000000      10466.000000                0.0
# 25%    -24607.750000    1941.000000      16998.250000                0.0
# 50%    -21146.500000    1951.500000      21146.500000                0.0
# 75%    -16998.250000    1963.250000      24607.750000                0.0
# 95%    -10466.000000    1982.000000      27468.000000                0.0
# max     -8493.000000    1987.000000      30256.000000                0.0
#
#        year_of_diagnosis
# count          96.000000
# mean         2009.145833
# std             5.005217
# min          1987.000000
# 5%           2000.000000
# 25%          2009.000000
# 50%          2011.000000
# 75%          2012.000000
# 95%          2013.000000
# max          2013.000000

# %%
clin_w = clin_w.drop_duplicates()
clin_w
# Out:
#                                   case_id case_submitter_id project_id  \
# 0    0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# 1    0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# 2    0bf573ac-cd1e-42d8-90cf-b30d7b08679c      TCGA-FA-A6HN  TCGA-DLBC
# 3    0bf573ac-cd1e-42d8-90cf-b30d7b08679c      TCGA-FA-A6HN  TCGA-DLBC
# 4    0e251c03-bf86-4ed8-b45d-3cbc97160502      TCGA-GS-A9U4  TCGA-DLBC
# 5    0e251c03-bf86-4ed8-b45d-3cbc97160502      TCGA-GS-A9U4  TCGA-DLBC
# 6    0e9fcccc-0630-408d-a121-2c6413824cb7      TCGA-FF-8062  TCGA-DLBC
# 7    0e9fcccc-0630-408d-a121-2c6413824cb7      TCGA-FF-8062  TCGA-DLBC
# 8    1843c82e-7a35-474f-9f79-c0a9af9aa09c      TCGA-FA-A4BB  TCGA-DLBC
# 9    1843c82e-7a35-474f-9f79-c0a9af9aa09c      TCGA-FA-A4BB  TCGA-DLBC
# 10   1d0db5d7-39ca-466d-96b3-0d278c5ea768      TCGA-FF-A7CW  TCGA-DLBC
# 11   1d0db5d7-39ca-466d-96b3-0d278c5ea768      TCGA-FF-A7CW  TCGA-DLBC
# 12   1ea575f1-f731-408b-a629-f5f4abab569e      TCGA-GS-A9TU  TCGA-DLBC
# 13   1ea575f1-f731-408b-a629-f5f4abab569e      TCGA-GS-A9TU  TCGA-DLBC
# 15   1f971af1-6772-4fe6-8d35-bbe527a037fe      TCGA-FF-8041  TCGA-DLBC
# 16   1f971af1-6772-4fe6-8d35-bbe527a037fe      TCGA-FF-8041  TCGA-DLBC
# 18   25ff86af-beb4-480c-b706-f3fe0306f7cf      TCGA-RQ-A68N  TCGA-DLBC
# 19   25ff86af-beb4-480c-b706-f3fe0306f7cf      TCGA-RQ-A68N  TCGA-DLBC
# 20   29aff186-c321-4ff9-b81b-105e27e620ff      TCGA-GS-A9TW  TCGA-DLBC
# 21   29aff186-c321-4ff9-b81b-105e27e620ff      TCGA-GS-A9TW  TCGA-DLBC
# 22   29e3d122-15a1-4235-a356-b1a9f94ceb39      TCGA-FF-A7CX  TCGA-DLBC
# 23   29e3d122-15a1-4235-a356-b1a9f94ceb39      TCGA-FF-A7CX  TCGA-DLBC
# 24   31bbad4e-3789-42ec-9faa-1cb86970f723      TCGA-G8-6907  TCGA-DLBC
# 25   31bbad4e-3789-42ec-9faa-1cb86970f723      TCGA-G8-6907  TCGA-DLBC
# 26   33365d22-cb83-4d8e-a2d1-06b675f75f6e      TCGA-GS-A9TT  TCGA-DLBC
# 27   33365d22-cb83-4d8e-a2d1-06b675f75f6e      TCGA-GS-A9TT  TCGA-DLBC
# 28   3622cf29-600f-4410-84d4-a9afeb41c475      TCGA-G8-6914  TCGA-DLBC
# 29   3622cf29-600f-4410-84d4-a9afeb41c475      TCGA-G8-6914  TCGA-DLBC
# 30   3f5a897d-1eaa-4d4c-8324-27ac07c90927      TCGA-G8-6906  TCGA-DLBC
# 31   3f5a897d-1eaa-4d4c-8324-27ac07c90927      TCGA-G8-6906  TCGA-DLBC
# 34   45b0cf9f-a879-417f-8f39-7770552252c0      TCGA-GS-A9TQ  TCGA-DLBC
# 35   45b0cf9f-a879-417f-8f39-7770552252c0      TCGA-GS-A9TQ  TCGA-DLBC
# 37   4dd86ebd-ef16-4b2b-9ea0-5d1d7afef257      TCGA-RQ-AAAT  TCGA-DLBC
# 38   4dd86ebd-ef16-4b2b-9ea0-5d1d7afef257      TCGA-RQ-AAAT  TCGA-DLBC
# 39   58e66976-4507-4552-ac53-83a49a142dde      TCGA-GS-A9TX  TCGA-DLBC
# 40   58e66976-4507-4552-ac53-83a49a142dde      TCGA-GS-A9TX  TCGA-DLBC
# 41   5eff68ff-f6c3-40c9-9fc8-00e684a7b712      TCGA-GR-A4D9  TCGA-DLBC
# 42   5eff68ff-f6c3-40c9-9fc8-00e684a7b712      TCGA-GR-A4D9  TCGA-DLBC
# 43   67325322-483f-443f-9ffa-2a20d108a2fb      TCGA-FF-8046  TCGA-DLBC
# 44   67325322-483f-443f-9ffa-2a20d108a2fb      TCGA-FF-8046  TCGA-DLBC
# 45   69f23725-adca-48ac-9b33-80a7aae24cfe      TCGA-FA-A6HO  TCGA-DLBC
# 46   69f23725-adca-48ac-9b33-80a7aae24cfe      TCGA-FA-A6HO  TCGA-DLBC
# 47   6a21c948-cd85-4150-8c01-83017d7dc1ed      TCGA-G8-6324  TCGA-DLBC
# 48   6a21c948-cd85-4150-8c01-83017d7dc1ed      TCGA-G8-6324  TCGA-DLBC
# 49   6e9437f0-a4ed-475c-ab0e-bf1431c70a90      TCGA-GS-A9TY  TCGA-DLBC
# 50   6e9437f0-a4ed-475c-ab0e-bf1431c70a90      TCGA-GS-A9TY  TCGA-DLBC
# 51   7a589441-11ef-4158-87e7-3951d86bc2aa      TCGA-GR-7351  TCGA-DLBC
# 52   7a589441-11ef-4158-87e7-3951d86bc2aa      TCGA-GR-7351  TCGA-DLBC
# 53   a43e5f0e-a21f-48d8-97e0-084d413680b7      TCGA-FA-8693  TCGA-DLBC
# 54   a43e5f0e-a21f-48d8-97e0-084d413680b7      TCGA-FA-8693  TCGA-DLBC
# 55   a468e725-ad4b-411d-ac5c-2eacc68ec580      TCGA-G8-6909  TCGA-DLBC
# 56   a468e725-ad4b-411d-ac5c-2eacc68ec580      TCGA-G8-6909  TCGA-DLBC
# 57   a5b188f0-a6d3-4d4a-b04f-36d47ec05338      TCGA-FA-A4XK  TCGA-DLBC
# 58   a5b188f0-a6d3-4d4a-b04f-36d47ec05338      TCGA-FA-A4XK  TCGA-DLBC
# 59   a6923479-4e68-4ea8-87ed-e9642b9d43d5      TCGA-VB-A8QN  TCGA-DLBC
# 60   a6923479-4e68-4ea8-87ed-e9642b9d43d5      TCGA-VB-A8QN  TCGA-DLBC
# 61   a8e2df1e-4042-42af-9231-3a00e83489f0      TCGA-FF-8043  TCGA-DLBC
# 62   a8e2df1e-4042-42af-9231-3a00e83489f0      TCGA-FF-8043  TCGA-DLBC
# 63   b56bdbdb-43af-4a03-a072-54dd22d7550c      TCGA-FA-A86F  TCGA-DLBC
# 64   b56bdbdb-43af-4a03-a072-54dd22d7550c      TCGA-FA-A86F  TCGA-DLBC
# 65   c1c06604-5ae2-4a53-b9c0-eb210d38e3f0      TCGA-GR-A4D6  TCGA-DLBC
# 66   c1c06604-5ae2-4a53-b9c0-eb210d38e3f0      TCGA-GR-A4D6  TCGA-DLBC
# 67   c3d662ee-48d0-454a-bb0c-77d3338d3747      TCGA-GR-7353  TCGA-DLBC
# 68   c3d662ee-48d0-454a-bb0c-77d3338d3747      TCGA-GR-7353  TCGA-DLBC
# 70   c85f340e-584b-4f3b-b6a5-540491fc8ad2      TCGA-GS-A9TV  TCGA-DLBC
# 71   c85f340e-584b-4f3b-b6a5-540491fc8ad2      TCGA-GS-A9TV  TCGA-DLBC
# 72   c8cde9ea-89e9-4ee8-8a46-417a48f6d3ab      TCGA-FF-8061  TCGA-DLBC
# 73   c8cde9ea-89e9-4ee8-8a46-417a48f6d3ab      TCGA-FF-8061  TCGA-DLBC
# 76   d7df78b5-24f1-4ff4-bd9b-f0e6bec8289a      TCGA-GR-A4D4  TCGA-DLBC
# 77   d7df78b5-24f1-4ff4-bd9b-f0e6bec8289a      TCGA-GR-A4D4  TCGA-DLBC
# 79   dc87a809-95de-4eb7-a1c2-2650475f2d7e      TCGA-RQ-A6JB  TCGA-DLBC
# 80   dc87a809-95de-4eb7-a1c2-2650475f2d7e      TCGA-RQ-A6JB  TCGA-DLBC
# 81   e56e4d9c-052e-4ec6-a81b-dbd53e9c8ffe      TCGA-FM-8000  TCGA-DLBC
# 82   e56e4d9c-052e-4ec6-a81b-dbd53e9c8ffe      TCGA-FM-8000  TCGA-DLBC
# 83   e6365b38-bc44-400c-b4aa-18ce8ff5bfce      TCGA-FA-A82F  TCGA-DLBC
# 84   e6365b38-bc44-400c-b4aa-18ce8ff5bfce      TCGA-FA-A82F  TCGA-DLBC
# 85   ea54dbad-1b23-41cc-9378-d4002a8fca51      TCGA-G8-6325  TCGA-DLBC
# 86   ea54dbad-1b23-41cc-9378-d4002a8fca51      TCGA-G8-6325  TCGA-DLBC
# 87   ed746cb9-0f2f-48ce-923a-3a9f9f00b331      TCGA-FA-A7DS  TCGA-DLBC
# 88   ed746cb9-0f2f-48ce-923a-3a9f9f00b331      TCGA-FA-A7DS  TCGA-DLBC
# 89   eda9496e-be80-4a13-bf06-89f0cc9e937f      TCGA-GS-A9TZ  TCGA-DLBC
# 90   eda9496e-be80-4a13-bf06-89f0cc9e937f      TCGA-GS-A9TZ  TCGA-DLBC
# 91   f0a326d2-1f3e-4a5d-bca8-32aaccc52338      TCGA-FF-8042  TCGA-DLBC
# 92   f0a326d2-1f3e-4a5d-bca8-32aaccc52338      TCGA-FF-8042  TCGA-DLBC
# 94   f553f1a9-ecf2-4783-a609-6adca7c4c597      TCGA-FF-A7CQ  TCGA-DLBC
# 95   f553f1a9-ecf2-4783-a609-6adca7c4c597      TCGA-FF-A7CQ  TCGA-DLBC
# 96   f784bc3a-751b-4025-aab2-0af2f6f24266      TCGA-FF-A7CR  TCGA-DLBC
# 97   f784bc3a-751b-4025-aab2-0af2f6f24266      TCGA-FF-A7CR  TCGA-DLBC
# 98   f855dad1-6ffc-493e-ba6c-970874bc9210      TCGA-GR-A4D5  TCGA-DLBC
# 99   f855dad1-6ffc-493e-ba6c-970874bc9210      TCGA-GR-A4D5  TCGA-DLBC
# 100  f8cf647b-1447-4ac3-8c43-bef07765cabf      TCGA-G8-6326  TCGA-DLBC
# 101  f8cf647b-1447-4ac3-8c43-bef07765cabf      TCGA-G8-6326  TCGA-DLBC
# 102  f978cb0f-d319-4c01-b4c5-23ae1403a106      TCGA-FF-8047  TCGA-DLBC
# 103  f978cb0f-d319-4c01-b4c5-23ae1403a106      TCGA-FF-8047  TCGA-DLBC
# 104  fdecb74f-ac4e-46b1-b23a-5f7fde96ef9f      TCGA-GS-A9U3  TCGA-DLBC
# 105  fdecb74f-ac4e-46b1-b23a-5f7fde96ef9f      TCGA-GS-A9U3  TCGA-DLBC
#
#     age_at_index  days_to_birth days_to_death               ethnicity  gender  \
# 0             61         -22454           248  not hispanic or latino  female
# 1             61         -22454           248  not hispanic or latino  female
# 2             73         -27025            58  not hispanic or latino    male
# 3             73         -27025            58  not hispanic or latino    male
# 4             27         -10075           391      hispanic or latino  female
# 5             27         -10075           391      hispanic or latino  female
# 6             60         -21959          None  not hispanic or latino  female
# 7             60         -21959          None  not hispanic or latino  female
# 8             67         -24590          None  not hispanic or latino    male
# 9             67         -24590          None  not hispanic or latino    male
# 10            72         -26520          None  not hispanic or latino    male
# 11            72         -26520          None  not hispanic or latino    male
# 12            45         -16720          None      hispanic or latino    male
# 13            45         -16720          None      hispanic or latino    male
# 15            28         -10466          None  not hispanic or latino  female
# 16            28         -10466          None  not hispanic or latino  female
# 18            63         -23127          None      hispanic or latino    male
# 19            63         -23127          None      hispanic or latino    male
# 20            23          -8493          None      hispanic or latino  female
# 21            23          -8493          None      hispanic or latino  female
# 22            46         -16924          None  not hispanic or latino    male
# 23            46         -16924          None  not hispanic or latino    male
# 24            57         -21021           595  not hispanic or latino  female
# 25            57         -21021           595  not hispanic or latino  female
# 26            70         -25794          None      hispanic or latino    male
# 27            70         -25794          None      hispanic or latino    male
# 28            67         -24569          None  not hispanic or latino    male
# 29            67         -24569          None  not hispanic or latino    male
# 30            58         -21272          6425  not hispanic or latino    male
# 31            58         -21272          6425  not hispanic or latino    male
# 34            69         -25292          None      hispanic or latino  female
# 35            69         -25292          None      hispanic or latino  female
# 37            63         -23178          None      hispanic or latino  female
# 38            63         -23178          None      hispanic or latino  female
# 39            37         -13708          None      hispanic or latino    male
# 40            37         -13708          None      hispanic or latino    male
# 41            66         -24405          None  not hispanic or latino  female
# 42            66         -24405          None  not hispanic or latino  female
# 43            51         -18853          None  not hispanic or latino    male
# 44            51         -18853          None  not hispanic or latino    male
# 45            58         -21330          None  not hispanic or latino  female
# 46            58         -21330          None  not hispanic or latino  female
# 47            43         -15750          1252  not hispanic or latino  female
# 48            43         -15750          1252  not hispanic or latino  female
# 49            82         -30256          None      hispanic or latino  female
# 50            82         -30256          None      hispanic or latino  female
# 51            56         -20812          None  not hispanic or latino  female
# 52            56         -20812          None  not hispanic or latino  female
# 53            75         -27468          None  not hispanic or latino    male
# 54            75         -27468          None  not hispanic or latino    male
# 55            67         -24661          3553  not hispanic or latino    male
# 56            67         -24661          3553  not hispanic or latino    male
# 57            40         -14723           708  not hispanic or latino    male
# 58            40         -14723           708  not hispanic or latino    male
# 59            55         -20270          None  not hispanic or latino    male
# 60            55         -20270          None  not hispanic or latino    male
# 61            70         -25612          None  not hispanic or latino  female
# 62            70         -25612          None  not hispanic or latino  female
# 63            64         -23641          None  not hispanic or latino  female
# 64            64         -23641          None  not hispanic or latino  female
# 65            54         -19838          None  not hispanic or latino  female
# 66            54         -19838          None  not hispanic or latino  female
# 67            36         -13317          None  not hispanic or latino    male
# 68            36         -13317          None  not hispanic or latino    male
# 70            40         -14838          None      hispanic or latino  female
# 71            40         -14838          None      hispanic or latino  female
# 72            42         -15358          None  not hispanic or latino    male
# 73            42         -15358          None  not hispanic or latino    male
# 76            57         -20888          None  not hispanic or latino  female
# 77            57         -20888          None  not hispanic or latino  female
# 79            62         -22859          None  not hispanic or latino  female
# 80            62         -22859          None  not hispanic or latino  female
# 81            70         -25724          None  not hispanic or latino  female
# 82            70         -25724          None  not hispanic or latino  female
# 83            48         -17819          None  not hispanic or latino  female
# 84            48         -17819          None  not hispanic or latino  female
# 85            69         -25256          None  not hispanic or latino    male
# 86            69         -25256          None  not hispanic or latino    male
# 87            54         -20087          None  not hispanic or latino  female
# 88            54         -20087          None  not hispanic or latino  female
# 89            51         -18691          None      hispanic or latino    male
# 90            51         -18691          None      hispanic or latino    male
# 91            57         -21005          None  not hispanic or latino  female
# 92            57         -21005          None  not hispanic or latino  female
# 94            74         -27255          None  not hispanic or latino    male
# 95            74         -27255          None  not hispanic or latino    male
# 96            61         -22471           313  not hispanic or latino    male
# 97            61         -22471           313  not hispanic or latino    male
# 98            46         -17023          None  not hispanic or latino  female
# 99            46         -17023          None  not hispanic or latino  female
# 100           52         -19238          None  not hispanic or latino    male
# 101           52         -19238          None  not hispanic or latino    male
# 102           38         -13996          None  not hispanic or latino  female
# 103           38         -13996          None  not hispanic or latino  female
# 104           77         -28474          None      hispanic or latino  female
# 105           77         -28474          None      hispanic or latino  female
#
#                           race vital_status  year_of_birth year_of_death  \
# 0                        asian         Dead           1952          None
# 1                        asian         Dead           1952          None
# 2                        asian         Dead           1940          None
# 3                        asian         Dead           1940          None
# 4                        white         Dead           1984          2012
# 5                        white         Dead           1984          2012
# 6                        asian        Alive           1951          None
# 7                        asian        Alive           1951          None
# 8                        white        Alive           1945          None
# 9                        white        Alive           1945          None
# 10                       asian        Alive           1940          None
# 11                       asian        Alive           1940          None
# 12                       white        Alive           1959          None
# 13                       white        Alive           1959          None
# 15                       asian        Alive           1982          None
# 16                       asian        Alive           1982          None
# 18                       white        Alive           1949          None
# 19                       white        Alive           1949          None
# 20                       white        Alive           1987          None
# 21                       white        Alive           1987          None
# 22                       asian        Alive           1965          None
# 23                       asian        Alive           1965          None
# 24                       white         Dead           1943          2001
# 25                       white         Dead           1943          2001
# 26                       white        Alive           1941          None
# 27                       white        Alive           1941          None
# 28                       white        Alive           1929          None
# 29                       white        Alive           1929          None
# 30                       white         Dead           1929          2004
# 31                       white         Dead           1929          2004
# 34                       white        Alive           1943          None
# 35                       white        Alive           1943          None
# 37                       white        Alive           1950          None
# 38                       white        Alive           1950          None
# 39                       white        Alive           1974          None
# 40                       white        Alive           1974          None
# 41                       white        Alive           1943          None
# 42                       white        Alive           1943          None
# 43                       asian        Alive           1960          None
# 44                       asian        Alive           1960          None
# 45                       asian        Alive           1955          None
# 46                       asian        Alive           1955          None
# 47   black or african american         Dead           1963          2009
# 48   black or african american         Dead           1963          2009
# 49                       white        Alive           1923          None
# 50                       white        Alive           1923          None
# 51                       white        Alive           1945          None
# 52                       white        Alive           1945          None
# 53                       white        Alive           1937          None
# 54                       white        Alive           1937          None
# 55                       white         Dead           1935          None
# 56                       white         Dead           1935          None
# 57                       asian         Dead           1972          None
# 58                       asian         Dead           1972          None
# 59                       white        Alive           1958          None
# 60                       white        Alive           1958          None
# 61                       asian        Alive           1940          None
# 62                       asian        Alive           1940          None
# 63                       white        Alive           1949          None
# 64                       white        Alive           1949          None
# 65                       asian        Alive           1956          None
# 66                       asian        Alive           1956          None
# 67                       white        Alive           1969          None
# 68                       white        Alive           1969          None
# 70                       white        Alive           1973          None
# 71                       white        Alive           1973          None
# 72                       asian        Alive           1968          None
# 73                       asian        Alive           1968          None
# 76                       white        Alive           1953          None
# 77                       white        Alive           1953          None
# 79                       white        Alive           1949          None
# 80                       white        Alive           1949          None
# 81                       white        Alive           1941          None
# 82                       white        Alive           1941          None
# 83                       asian        Alive           1965          None
# 84                       asian        Alive           1965          None
# 85                       white        Alive           1939          None
# 86                       white        Alive           1939          None
# 87                       asian        Alive           1959          None
# 88                       asian        Alive           1959          None
# 89                       white        Alive           1961          None
# 90                       white        Alive           1961          None
# 91                       asian        Alive           1953          None
# 92                       asian        Alive           1953          None
# 94                       asian        Alive           1936          None
# 95                       asian        Alive           1936          None
# 96                       asian         Dead           1951          2012
# 97                       asian         Dead           1951          2012
# 98                       white        Alive           1964          None
# 99                       white        Alive           1964          None
# 100                      white        Alive           1957          None
# 101                      white        Alive           1957          None
# 102                      asian        Alive           1973          None
# 103                      asian        Alive           1973          None
# 104                      white        Alive           1928          None
# 105                      white        Alive           1928          None
#
#      age_at_diagnosis ann_arbor_b_symptoms ann_arbor_clinical_stage  \
# 0               22454                   No                  Stage I
# 1               22454                   No                  Stage I
# 2               27025                   No                     None
# 3               27025                   No                     None
# 4               10075                   No                 Stage II
# 5               10075                   No                 Stage II
# 6               21959                   No                  Stage I
# 7               21959                   No                  Stage I
# 8               24590                  Yes                 Stage IV
# 9               24590                  Yes                 Stage IV
# 10              26520                   No                 Stage II
# 11              26520                   No                 Stage II
# 12              16720                   No                 Stage II
# 13              16720                   No                 Stage II
# 15              10466                   No                  Stage I
# 16              10466                   No                  Stage I
# 18              23127                 None                     None
# 19              23127                 None                     None
# 20               8493                   No                 Stage II
# 21               8493                   No                 Stage II
# 22              16924                  Yes                 Stage IV
# 23              16924                  Yes                 Stage IV
# 24              21021                   No                 Stage IV
# 25              21021                   No                 Stage IV
# 26              25794                   No                 Stage IV
# 27              25794                   No                 Stage IV
# 28              24569                   No                Stage III
# 29              24569                   No                Stage III
# 30              21272                  Yes                     None
# 31              21272                  Yes                     None
# 34              25292                   No                 Stage II
# 35              25292                   No                 Stage II
# 37              23178                 None                     None
# 38              23178                 None                     None
# 39              13708                   No                  Stage I
# 40              13708                   No                  Stage I
# 41              24405                   No                 Stage IV
# 42              24405                   No                 Stage IV
# 43              18853                   No                 Stage II
# 44              18853                   No                 Stage II
# 45              21330                   No                     None
# 46              21330                   No                     None
# 47              15750                   No                 Stage IV
# 48              15750                   No                 Stage IV
# 49              30256                   No                  Stage I
# 50              30256                   No                  Stage I
# 51              20812                   No                  Stage I
# 52              20812                   No                  Stage I
# 53              27468                   No                  Stage I
# 54              27468                   No                  Stage I
# 55              24661                   No                Stage III
# 56              24661                   No                Stage III
# 57              14723                   No                 Stage II
# 58              14723                   No                 Stage II
# 59              20270                  Yes                Stage III
# 60              20270                  Yes                Stage III
# 61              25612                   No                 Stage II
# 62              25612                   No                 Stage II
# 63              23641                   No                Stage III
# 64              23641                   No                Stage III
# 65              19838                   No                  Stage I
# 66              19838                   No                  Stage I
# 67              13317                   No                 Stage II
# 68              13317                   No                 Stage II
# 70              14838                   No                 Stage II
# 71              14838                   No                 Stage II
# 72              15358                  Yes                 Stage II
# 73              15358                  Yes                 Stage II
# 76              20888                  Yes                 Stage IV
# 77              20888                  Yes                 Stage IV
# 79              22859                   No                     None
# 80              22859                   No                     None
# 81              25724                   No                 Stage II
# 82              25724                   No                 Stage II
# 83              17819                   No                 Stage II
# 84              17819                   No                 Stage II
# 85              25256                  Yes                 Stage IV
# 86              25256                  Yes                 Stage IV
# 87              20087                   No                 Stage II
# 88              20087                   No                 Stage II
# 89              18691                   No                 Stage II
# 90              18691                   No                 Stage II
# 91              21005                   No                 Stage II
# 92              21005                   No                 Stage II
# 94              27255                  Yes                 Stage IV
# 95              27255                  Yes                 Stage IV
# 96              22471                   No                 Stage IV
# 97              22471                   No                 Stage IV
# 98              17023                  Yes                 Stage IV
# 99              17023                  Yes                 Stage IV
# 100             19238                  Yes                 Stage IV
# 101             19238                  Yes                 Stage IV
# 102             13996                   No                 Stage II
# 103             13996                   No                 Stage II
# 104             28474                  Yes                Stage III
# 105             28474                  Yes                Stage III
#
#     ann_arbor_extranodal_involvement classification_of_tumor  \
# 0                                 No            not reported
# 1                                 No            not reported
# 2                                 No            not reported
# 3                                 No            not reported
# 4                                 No            not reported
# 5                                 No            not reported
# 6                                Yes            not reported
# 7                                Yes            not reported
# 8                                Yes            not reported
# 9                                Yes            not reported
# 10                               Yes            not reported
# 11                               Yes            not reported
# 12                                No            not reported
# 13                                No            not reported
# 15                                No            not reported
# 16                                No            not reported
# 18                              None            not reported
# 19                              None            not reported
# 20                                No            not reported
# 21                                No            not reported
# 22                               Yes            not reported
# 23                               Yes            not reported
# 24                                No            not reported
# 25                                No            not reported
# 26                               Yes            not reported
# 27                               Yes            not reported
# 28                                No            not reported
# 29                                No            not reported
# 30                               Yes            not reported
# 31                               Yes            not reported
# 34                                No            not reported
# 35                                No            not reported
# 37                              None            not reported
# 38                              None            not reported
# 39                                No            not reported
# 40                                No            not reported
# 41                               Yes            not reported
# 42                               Yes            not reported
# 43                                No            not reported
# 44                                No            not reported
# 45                                No            not reported
# 46                                No            not reported
# 47                               Yes            not reported
# 48                               Yes            not reported
# 49                                No            not reported
# 50                                No            not reported
# 51                               Yes            not reported
# 52                               Yes            not reported
# 53                               Yes            not reported
# 54                               Yes            not reported
# 55                                No            not reported
# 56                                No            not reported
# 57                               Yes            not reported
# 58                               Yes            not reported
# 59                               Yes            not reported
# 60                               Yes            not reported
# 61                               Yes            not reported
# 62                               Yes            not reported
# 63                                No            not reported
# 64                                No            not reported
# 65                                No            not reported
# 66                                No            not reported
# 67                                No            not reported
# 68                                No            not reported
# 70                                No            not reported
# 71                                No            not reported
# 72                               Yes            not reported
# 73                               Yes            not reported
# 76                               Yes            not reported
# 77                               Yes            not reported
# 79                               Yes            not reported
# 80                               Yes            not reported
# 81                               Yes            not reported
# 82                               Yes            not reported
# 83                                No            not reported
# 84                                No            not reported
# 85                                No            not reported
# 86                                No            not reported
# 87                                No            not reported
# 88                                No            not reported
# 89                                No            not reported
# 90                                No            not reported
# 91                                No            not reported
# 92                                No            not reported
# 94                               Yes            not reported
# 95                               Yes            not reported
# 96                               Yes            not reported
# 97                               Yes            not reported
# 98                               Yes            not reported
# 99                               Yes            not reported
# 100                              Yes            not reported
# 101                              Yes            not reported
# 102                               No            not reported
# 103                               No            not reported
# 104                               No            not reported
# 105                               No            not reported
#
#      days_to_diagnosis days_to_last_follow_up icd_10_code  \
# 0                    0                     22       C48.1
# 1                    0                     22       C48.1
# 2                    0                      6       C83.3
# 3                    0                      6       C83.3
# 4                    0                   None       C83.3
# 5                    0                   None       C83.3
# 6                    0                    679       C83.3
# 7                    0                    679       C83.3
# 8                    0                    132       C83.3
# 9                    0                    132       C83.3
# 10                   0                    791       C83.3
# 11                   0                    791       C83.3
# 12                   0                   3897       C83.3
# 13                   0                   3897       C83.3
# 15                   0                   1081       C38.1
# 16                   0                   1081       C38.1
# 18                   0                    788       C71.7
# 19                   0                    788       C71.7
# 20                   0                   1617       C83.3
# 21                   0                   1617       C83.3
# 22                   0                    385       C49.0
# 23                   0                    385       C49.0
# 24                   0                   None       C83.3
# 25                   0                   None       C83.3
# 26                   0                   1163      C62.90
# 27                   0                   1163      C62.90
# 28                   0                   5980       C83.3
# 29                   0                   5980       C83.3
# 30                   0                   None       C83.3
# 31                   0                   None       C83.3
# 34                   0                    982       C83.3
# 35                   0                    982       C83.3
# 37                   0                     17       C71.6
# 38                   0                     17       C71.6
# 39                   0                   1373       C83.3
# 40                   0                   1373       C83.3
# 41                   0                   1739       C83.3
# 42                   0                   1739       C83.3
# 43                   0                    751       C08.0
# 44                   0                    751       C08.0
# 45                   0                    749       C83.3
# 46                   0                    749       C83.3
# 47                   0                   None       C83.3
# 48                   0                   None       C83.3
# 49                   0                   2616       C83.3
# 50                   0                   2616       C83.3
# 51                   0                   4578       C83.3
# 52                   0                   4578       C83.3
# 53                   0                    132       C83.3
# 54                   0                    132       C83.3
# 55                   0                   3227       C77.1
# 56                   0                   3227       C77.1
# 57                   0                    456       C83.3
# 58                   0                    456       C83.3
# 59                   0                      0       C83.3
# 60                   0                      0       C83.3
# 61                   0                    965       C83.3
# 62                   0                    965       C83.3
# 63                   0                    553       C83.3
# 64                   0                    553       C83.3
# 65                   0                   1334       C83.3
# 66                   0                   1334       C83.3
# 67                   0                   2983       C83.3
# 68                   0                   2983       C83.3
# 70                   0                    730       C83.3
# 71                   0                    730       C83.3
# 72                   0                    832       C83.3
# 73                   0                    832       C83.3
# 76                   0                   1581       C83.3
# 77                   0                   1581       C83.3
# 79                   0                      1       C83.3
# 80                   0                      1       C83.3
# 81                   0                    972       C83.3
# 82                   0                    972       C83.3
# 83                   0                    427       C83.3
# 84                   0                    427       C83.3
# 85                   0                   1581       C83.3
# 86                   0                   1581       C83.3
# 87                   0                    719       C50.9
# 88                   0                    719       C50.9
# 89                   0                    765       C83.3
# 90                   0                    765       C83.3
# 91                   0                    946       C83.3
# 92                   0                    946       C83.3
# 94                   0                    298       C83.3
# 95                   0                    298       C83.3
# 96                   0                   None       C83.3
# 97                   0                   None       C83.3
# 98                   0                   1299       C83.3
# 99                   0                   1299       C83.3
# 100                  0                   2131       C48.1
# 101                  0                   2131       C48.1
# 102                  0                    126       C83.3
# 103                  0                    126       C83.3
# 104                  0                   3394       C83.3
# 105                  0                   3394       C83.3
#
#     last_known_disease_status morphology  \
# 0                not reported     9680/3
# 1                not reported     9680/3
# 2                not reported     9680/3
# 3                not reported     9680/3
# 4                not reported     9680/3
# 5                not reported     9680/3
# 6                not reported     9680/3
# 7                not reported     9680/3
# 8                not reported     9680/3
# 9                not reported     9680/3
# 10               not reported     9680/3
# 11               not reported     9680/3
# 12               not reported     9680/3
# 13               not reported     9680/3
# 15               not reported     9680/3
# 16               not reported     9680/3
# 18               not reported     9680/3
# 19               not reported     9680/3
# 20               not reported     9680/3
# 21               not reported     9680/3
# 22               not reported     9680/3
# 23               not reported     9680/3
# 24               not reported     9680/3
# 25               not reported     9680/3
# 26               not reported     9680/3
# 27               not reported     9680/3
# 28               not reported     9680/3
# 29               not reported     9680/3
# 30               not reported     9680/3
# 31               not reported     9680/3
# 34               not reported     9680/3
# 35               not reported     9680/3
# 37               not reported     9680/3
# 38               not reported     9680/3
# 39               not reported     9680/3
# 40               not reported     9680/3
# 41               not reported     9680/3
# 42               not reported     9680/3
# 43               not reported     9680/3
# 44               not reported     9680/3
# 45               not reported     9680/3
# 46               not reported     9680/3
# 47               not reported     9680/3
# 48               not reported     9680/3
# 49               not reported     9680/3
# 50               not reported     9680/3
# 51               not reported     9680/3
# 52               not reported     9680/3
# 53               not reported     9680/3
# 54               not reported     9680/3
# 55               not reported     9680/3
# 56               not reported     9680/3
# 57               not reported     9680/3
# 58               not reported     9680/3
# 59               not reported     9680/3
# 60               not reported     9680/3
# 61               not reported     9680/3
# 62               not reported     9680/3
# 63               not reported     9680/3
# 64               not reported     9680/3
# 65               not reported     9680/3
# 66               not reported     9680/3
# 67               not reported     9680/3
# 68               not reported     9680/3
# 70               not reported     9680/3
# 71               not reported     9680/3
# 72               not reported     9680/3
# 73               not reported     9680/3
# 76               not reported     9680/3
# 77               not reported     9680/3
# 79               not reported     9680/3
# 80               not reported     9680/3
# 81               not reported     9680/3
# 82               not reported     9680/3
# 83               not reported     9680/3
# 84               not reported     9680/3
# 85               not reported     9680/3
# 86               not reported     9680/3
# 87               not reported     9680/3
# 88               not reported     9680/3
# 89               not reported     9680/3
# 90               not reported     9680/3
# 91               not reported     9680/3
# 92               not reported     9680/3
# 94               not reported     9680/3
# 95               not reported     9680/3
# 96               not reported     9680/3
# 97               not reported     9680/3
# 98               not reported     9680/3
# 99               not reported     9680/3
# 100              not reported     9680/3
# 101              not reported     9680/3
# 102              not reported     9680/3
# 103              not reported     9680/3
# 104              not reported     9680/3
# 105              not reported     9680/3
#
#                                   primary_diagnosis prior_malignancy  \
# 0    Malignant lymphoma, large B-cell, diffuse, NOS               no
# 1    Malignant lymphoma, large B-cell, diffuse, NOS               no
# 2    Malignant lymphoma, large B-cell, diffuse, NOS               no
# 3    Malignant lymphoma, large B-cell, diffuse, NOS               no
# 4    Malignant lymphoma, large B-cell, diffuse, NOS               no
# 5    Malignant lymphoma, large B-cell, diffuse, NOS               no
# 6    Malignant lymphoma, large B-cell, diffuse, NOS               no
# 7    Malignant lymphoma, large B-cell, diffuse, NOS               no
# 8    Malignant lymphoma, large B-cell, diffuse, NOS               no
# 9    Malignant lymphoma, large B-cell, diffuse, NOS               no
# 10   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 11   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 12   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 13   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 15   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 16   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 18   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 19   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 20   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 21   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 22   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 23   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 24   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 25   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 26   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 27   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 28   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 29   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 30   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 31   Malignant lymphoma, large B-cell, diffuse, NOS               no
# 34   Malignant lymphoma, large B-cell, diffuse, NOS               no
# ...
# 13                                     Lymph nodes of inguinal region or leg
# 15                                                      Anterior mediastinum
# 16                                                      Anterior mediastinum
# 18                                                                Brain stem
# 19                                                                Brain stem
# 20                                              Lymph nodes of axilla or arm
# 21                                              Lymph nodes of axilla or arm
# 22   Connective, subcutaneous and other soft tissues of head, face, and neck
# 23   Connective, subcutaneous and other soft tissues of head, face, and neck
# 24                                        Lymph nodes of head, face and neck
# 25                                        Lymph nodes of head, face and neck
# 26                                                               Testis, NOS
# 27                                                               Testis, NOS
# 28                                        Lymph nodes of head, face and neck
# 29                                        Lymph nodes of head, face and neck
# 30                                               Intra-abdominal lymph nodes
# 31                                               Intra-abdominal lymph nodes
# 34                                     Lymph nodes of inguinal region or leg
# 35                                     Lymph nodes of inguinal region or leg
# 37                                                           Cerebellum, NOS
# 38                                                           Cerebellum, NOS
# 39                                     Lymph nodes of inguinal region or leg
# 40                                     Lymph nodes of inguinal region or leg
# 41                                        Lymph nodes of head, face and neck
# 42                                        Lymph nodes of head, face and neck
# 43                                                       Submandibular gland
# 44                                                       Submandibular gland
# 45                                        Lymph nodes of head, face and neck
# 46                                        Lymph nodes of head, face and neck
# 47                                               Intra-abdominal lymph nodes
# 48                                               Intra-abdominal lymph nodes
# 49                                              Lymph nodes of axilla or arm
# 50                                              Lymph nodes of axilla or arm
# 51                                                             Thyroid gland
# 52                                                             Thyroid gland
# 53                                                              Stomach, NOS
# 54                                                              Stomach, NOS
# 55                                                 Intrathoracic lymph nodes
# 56                                                 Intrathoracic lymph nodes
# 57                                                                   Jejunum
# 58                                                                   Jejunum
# 59                                                              Stomach, NOS
# 60                                                              Stomach, NOS
# 61                                                                Colon, NOS
# 62                                                                Colon, NOS
# 63                                              Lymph nodes of axilla or arm
# 64                                              Lymph nodes of axilla or arm
# 65                                        Lymph nodes of head, face and neck
# 66                                        Lymph nodes of head, face and neck
# 67                                        Lymph nodes of head, face and neck
# 68                                        Lymph nodes of head, face and neck
# 70                                        Lymph nodes of head, face and neck
# 71                                        Lymph nodes of head, face and neck
# 72                                                      Small intestine, NOS
# 73                                                      Small intestine, NOS
# 76                      Connective, subcutaneous and other soft tissues, NOS
# 77                      Connective, subcutaneous and other soft tissues, NOS
# 79                             Bones of skull and face and associated joints
# 80                             Bones of skull and face and associated joints
# 81                                                                Colon, NOS
# 82                                                                Colon, NOS
# 83                                                      Small intestine, NOS
# 84                                                      Small intestine, NOS
# 85                                               Intra-abdominal lymph nodes
# 86                                               Intra-abdominal lymph nodes
# 87                                                               Breast, NOS
# 88                                                               Breast, NOS
# 89                                        Lymph nodes of head, face and neck
# 90                                        Lymph nodes of head, face and neck
# 91                                        Lymph nodes of head, face and neck
# 92                                        Lymph nodes of head, face and neck
# 94                                        Lymph nodes of head, face and neck
# 95                                        Lymph nodes of head, face and neck
# 96                                        Lymph nodes of head, face and neck
# 97                                        Lymph nodes of head, face and neck
# 98                                        Lymph nodes of head, face and neck
# 99                                        Lymph nodes of head, face and neck
# 100                                            Specified parts of peritoneum
# 101                                            Specified parts of peritoneum
# 102                                       Lymph nodes of head, face and neck
# 103                                       Lymph nodes of head, face and neck
# 104                                    Lymph nodes of inguinal region or leg
# 105                                    Lymph nodes of inguinal region or leg
#
#       tumor_grade  year_of_diagnosis treatment_or_therapy  \
# 0    not reported               2013                  yes
# 1    not reported               2013                   no
# 2    not reported               2013                   no
# 3    not reported               2013                  yes
# 4    not reported               2011                  yes
# 5    not reported               2011                   no
# 6    not reported               2011                  yes
# 7    not reported               2011                   no
# 8    not reported               2012                   no
# 9    not reported               2012                  yes
# 10   not reported               2012                  yes
# 11   not reported               2012                   no
# 12   not reported               2004                  yes
# 13   not reported               2004                  yes
# 15   not reported               2010                   no
# 16   not reported               2010                  yes
# 18   not reported               2012                   no
# 19   not reported               2012                  yes
# 20   not reported               2010                  yes
# 21   not reported               2010                  yes
# 22   not reported               2011                  yes
# 23   not reported               2011                   no
# 24   not reported               2000                   no
# 25   not reported               2000                  yes
# 26   not reported               2011                  yes
# 27   not reported               2011                  yes
# 28   not reported               1996                   no
# 29   not reported               1996                  yes
# 30   not reported               1987                   no
# 31   not reported               1987                  yes
# 34   not reported               2012                  yes
# 35   not reported               2012                   no
# 37   not reported               2013                   no
# 38   not reported               2013                   no
# 39   not reported               2011                  yes
# 40   not reported               2011                  yes
# 41   not reported               2009                   no
# 42   not reported               2009                  yes
# 43   not reported               2011                   no
# 44   not reported               2011                  yes
# 45   not reported               2013                   no
# 46   not reported               2013                  yes
# 47   not reported               2006                  yes
# 48   not reported               2006                   no
# 49   not reported               2005                   no
# 50   not reported               2005                  yes
# 51   not reported               2001                  yes
# 52   not reported               2001                  yes
# 53   not reported               2012                  yes
# 54   not reported               2012                   no
# 55   not reported               2002                  yes
# 56   not reported               2002                   no
# 57   not reported               2012                   no
# 58   not reported               2012                   no
# 59   not reported               2013                   no
# 60   not reported               2013                   no
# 61   not reported               2010                   no
# 62   not reported               2010                  yes
# 63   not reported               2013                   no
# 64   not reported               2013                  yes
# 65   not reported               2010                   no
# 66   not reported               2010                  yes
# 67   not reported               2005                  yes
# 68   not reported               2005                   no
# 70   not reported               2013                  yes
# 71   not reported               2013                  yes
# 72   not reported               2010                  yes
# 73   not reported               2010                   no
# 76   not reported               2010                  yes
# 77   not reported               2010                   no
# 79   not reported               2011         not reported
# 80   not reported               2011         not reported
# 81   not reported               2011                  yes
# 82   not reported               2011                   no
# 83   not reported               2013                  yes
# 84   not reported               2013                   no
# 85   not reported               2008                  yes
# 86   not reported               2008                   no
# 87   not reported               2013                   no
# 88   not reported               2013                  yes
# 89   not reported               2012                  yes
# 90   not reported               2012                  yes
# 91   not reported               2010                   no
# 92   not reported               2010                  yes
# 94   not reported               2010                   no
# 95   not reported               2010                  yes
# 96   not reported               2012                  yes
# 97   not reported               2012                   no
# 98   not reported               2010                  yes
# 99   not reported               2010                   no
# 100  not reported               2009                  yes
# 101  not reported               2009                   no
# 102  not reported               2011                   no
# 103  not reported               2011                  yes
# 104  not reported               2005                   no
# 105  not reported               2005                  yes
#
#                   treatment_type
# 0    Pharmaceutical Therapy, NOS
# 1         Radiation Therapy, NOS
# 2         Radiation Therapy, NOS
# 3    Pharmaceutical Therapy, NOS
# 4    Pharmaceutical Therapy, NOS
# 5         Radiation Therapy, NOS
# 6    Pharmaceutical Therapy, NOS
# 7         Radiation Therapy, NOS
# 8         Radiation Therapy, NOS
# 9    Pharmaceutical Therapy, NOS
# 10   Pharmaceutical Therapy, NOS
# 11        Radiation Therapy, NOS
# 12        Radiation Therapy, NOS
# 13   Pharmaceutical Therapy, NOS
# 15        Radiation Therapy, NOS
# 16   Pharmaceutical Therapy, NOS
# 18        Radiation Therapy, NOS
# 19   Pharmaceutical Therapy, NOS
# 20   Pharmaceutical Therapy, NOS
# 21        Radiation Therapy, NOS
# 22   Pharmaceutical Therapy, NOS
# 23        Radiation Therapy, NOS
# 24        Radiation Therapy, NOS
# 25   Pharmaceutical Therapy, NOS
# 26   Pharmaceutical Therapy, NOS
# 27        Radiation Therapy, NOS
# 28        Radiation Therapy, NOS
# 29   Pharmaceutical Therapy, NOS
# 30        Radiation Therapy, NOS
# 31   Pharmaceutical Therapy, NOS
# 34   Pharmaceutical Therapy, NOS
# 35        Radiation Therapy, NOS
# 37   Pharmaceutical Therapy, NOS
# 38        Radiation Therapy, NOS
# 39   Pharmaceutical Therapy, NOS
# 40        Radiation Therapy, NOS
# 41        Radiation Therapy, NOS
# 42   Pharmaceutical Therapy, NOS
# 43        Radiation Therapy, NOS
# 44   Pharmaceutical Therapy, NOS
# 45        Radiation Therapy, NOS
# 46   Pharmaceutical Therapy, NOS
# 47   Pharmaceutical Therapy, NOS
# 48        Radiation Therapy, NOS
# 49        Radiation Therapy, NOS
# 50   Pharmaceutical Therapy, NOS
# 51   Pharmaceutical Therapy, NOS
# 52        Radiation Therapy, NOS
# 53   Pharmaceutical Therapy, NOS
# 54        Radiation Therapy, NOS
# 55   Pharmaceutical Therapy, NOS
# 56        Radiation Therapy, NOS
# 57   Pharmaceutical Therapy, NOS
# 58        Radiation Therapy, NOS
# 59        Radiation Therapy, NOS
# 60   Pharmaceutical Therapy, NOS
# 61        Radiation Therapy, NOS
# 62   Pharmaceutical Therapy, NOS
# 63        Radiation Therapy, NOS
# 64   Pharmaceutical Therapy, NOS
# 65        Radiation Therapy, NOS
# 66   Pharmaceutical Therapy, NOS
# 67   Pharmaceutical Therapy, NOS
# 68        Radiation Therapy, NOS
# 70   Pharmaceutical Therapy, NOS
# 71        Radiation Therapy, NOS
# 72   Pharmaceutical Therapy, NOS
# 73        Radiation Therapy, NOS
# 76   Pharmaceutical Therapy, NOS
# 77        Radiation Therapy, NOS
# 79        Radiation Therapy, NOS
# 80   Pharmaceutical Therapy, NOS
# 81   Pharmaceutical Therapy, NOS
# 82        Radiation Therapy, NOS
# 83   Pharmaceutical Therapy, NOS
# 84        Radiation Therapy, NOS
# 85   Pharmaceutical Therapy, NOS
# 86        Radiation Therapy, NOS
# 87        Radiation Therapy, NOS
# 88   Pharmaceutical Therapy, NOS
# 89        Radiation Therapy, NOS
# 90   Pharmaceutical Therapy, NOS
# 91        Radiation Therapy, NOS
# 92   Pharmaceutical Therapy, NOS
# 94        Radiation Therapy, NOS
# 95   Pharmaceutical Therapy, NOS
# 96   Pharmaceutical Therapy, NOS
# 97        Radiation Therapy, NOS
# 98   Pharmaceutical Therapy, NOS
# 99        Radiation Therapy, NOS
# 100  Pharmaceutical Therapy, NOS
# 101       Radiation Therapy, NOS
# 102       Radiation Therapy, NOS
# 103  Pharmaceutical Therapy, NOS
# 104       Radiation Therapy, NOS
# 105  Pharmaceutical Therapy, NOS

# %% [markdown]
# Дублирования записей нет, просто пациенты получали два вида терапии: Радиотерапию и Химиотерапию. И это занесено в разные строки. Надо преобразовать и занести в одну строку. Для каждого пациента.

# %%
clin_w['ter_01'] =
